# %%
import pandas as pd
import glob
from pathlib import Path

# %%
imputed_dir = Path("imputed_ohe_data")
simulated_dir = Path("simulated_data")
target_dir = Path("imputed_data")

# %%
for imputed_file in imputed_dir.glob("*.tsv"):
    # Build corresponding csv path with same stem (filename without extension)
    simulated_file = simulated_dir / str(imputed_file).split("/")[1]
    
    imputed_df = pd.read_csv(imputed_file, sep="\t", index_col=0)
    
    simulated_df = pd.read_csv(simulated_file, sep="\t", index_col=0)
    simulated_df.drop(columns=['type'], inplace=True)
    simulated_df = simulated_df.T.copy()
    simulated_df.replace({-99999.0 : pd.NA}, inplace=True)
    
    # Subset to OHE variables.
    ohe_cols = [col for col in imputed_df.columns if col.startswith("ohe")]
    non_ohe_cols = set(imputed_df.columns) - set(ohe_cols)
    ohe_df = imputed_df[ohe_cols].copy()
    
    ohe_vars = set([col[4:-4] for col in ohe_cols])
    var_to_columns = {var : [col for col in ohe_cols if (var in col)] for var in ohe_vars}
        
    trafo_df = pd.DataFrame(index=ohe_df.index, columns=list(ohe_vars))

    # Iterate over all OHE variables and choose maximum imputed value as category.
    for var in ohe_vars:
        for sample in trafo_df.index:
            # Check if sample-var pair has been NA in input data.
            if pd.isna(simulated_df.loc[sample, var]):
                # Search max value in OHE imputed file.
                var_categories = var_to_columns[var]
                col_values = {col : imputed_df.at[sample, col] for col in var_categories}
                max_col = max(col_values, key=col_values.get)
                max_category = float(max_col[-3:])
                # Set best category into imputed dataframe.
                trafo_df.loc[sample, var] = max_category
            else:
                # Set already existing value into aggregated dataframe.
                trafo_df.loc[sample, var] = simulated_df.loc[sample, var]

    # Combine imputed df with ohe-transformed imputed df.
    final_df = pd.concat([imputed_df[list(non_ohe_cols)], trafo_df], axis=1)
    target_file = target_dir / str(imputed_file).split("/")[1]
    final_df.to_csv(target_file, sep='\t', index=True)
# Out:
#              c028  Platelet mean volume [Entitic volume] in Blood  \
# Patient_1     0.0                                       10.300000
# Patient_2     0.0                                       10.100000
# Patient_3     0.0                                        8.900000
# Patient_4     0.0                                       10.523334
# Patient_6     0.0                                       10.200000
# ...           ...                                             ...
# Patient_47    0.0                                       10.469333
# Patient_228   0.0                                       10.154000
# Patient_237   0.0                                       10.324667
# Patient_407   0.0                                       10.420000
# Patient_463   0.0                                       10.164667
#
#              days_to_recurrence  d370  c800  Platelets [#/volume] in Blood  \
# Patient_1                 498.2   0.0   0.0                         156.00
# Patient_2                 357.0   0.0   0.0                         295.00
# Patient_3                 293.8   0.0   0.0                         225.00
# Patient_4                 862.2   1.0   0.0                         198.00
# Patient_6                 775.6   0.0   0.0                         217.00
# ...                         ...   ...   ...                            ...
# Patient_47               1825.6   0.0   0.2                         258.97
# Patient_228               172.0   0.0   0.0                         244.57
# Patient_237               180.0   0.0   0.0                         241.80
# Patient_407               376.6   0.0   0.0                         283.60
# Patient_463               861.4   0.2   0.0                         259.37
#
#              c322  survival_status  Eosinophils [#/volume] in Blood  c098  \
# Patient_1     0.0              1.0                         0.060000   0.0
# Patient_2     0.0              1.0                         0.110000   0.0
# Patient_3     0.0              1.0                         0.010000   0.0
# Patient_4     0.0              1.0                         0.100833   0.0
# Patient_6     0.0              1.0                         0.130000   0.0
# ...           ...              ...                              ...   ...
# Patient_47    0.0              1.0                         0.096167   0.0
# Patient_228   0.0              0.2                         0.176167   0.0
# Patient_237   0.0              1.0                         0.110000   0.2
# Patient_407   0.0              1.0                         0.086000   0.2
# Patient_463   0.0              0.0                         0.138167   0.4
#
#              ...  Basophils [#/volume] in Blood  days_to_last_information  \
# Patient_1    ...                         0.0200                    2258.0
# Patient_2    ...                         0.0300                    1753.0
# Patient_3    ...                         0.0100                     851.0
# Patient_4    ...                         0.0210                    2996.0
# Patient_6    ...                         0.0300                     991.0
# ...          ...                            ...                       ...
# Patient_47   ...                         0.0242                    4228.0
# Patient_228  ...                         0.0742                    1038.4
# Patient_237  ...                         0.0440                     212.0
# Patient_407  ...                         0.0300                    1220.0
# Patient_463  ...                         0.0342                    1355.0
#
#              c132  c099  \
# Patient_1     0.0   0.0
# Patient_2     0.0   0.0
# Patient_3     0.0   0.0
# Patient_4     0.0   0.0
# Patient_6     0.0   0.0
# ...           ...   ...
# Patient_47    0.0   0.0
# Patient_228   0.0   0.0
# Patient_237   0.0   0.0
# Patient_407   0.0   0.0
# Patient_463   0.0   0.0
#
#              Erythrocyte mean corpuscular hemoglobin concentration [Mass/volume]  \
# Patient_1                                            35.159999
# Patient_2                                            35.400002
# Patient_3                                            35.099998
# Patient_4                                            33.300000
# Patient_6                                            35.500000
# ...                                                        ...
# Patient_47                                           34.503000
# Patient_228                                          34.163000
# Patient_237                                          34.140000
# Patient_407                                          34.360000
# Patient_463                                          34.323000
#
#              c022  lymphovascular_invasion_L  c328  days_to_rfs_event  c020
# Patient_1     0.0                        1.0   0.0             2230.0   0.0
# Patient_2     0.0                        1.0   0.0              341.0   0.0
# Patient_3     0.0                        0.0   0.0              210.4   0.0
# Patient_4     0.0                        0.0   0.0              251.2   0.0
# Patient_6     0.0                        0.0   0.0              943.0   0.0
# ...           ...                        ...   ...                ...   ...
# Patient_47    0.0                        1.0   0.0             4204.0   0.0
# Patient_228   0.0                        0.0   0.0                6.0   0.0
# Patient_237   0.0                        0.0   0.0              170.0   0.0
# Patient_407   0.0                        0.0   0.0             1199.0   0.0
# Patient_463   0.0                        0.0   0.0              917.0   0.0
#
# [763 rows x 69 columns]
#              c068  c028  Platelet mean volume [Entitic volume] in Blood  \
# Patient_1     0.0   0.0                                        9.960000
# Patient_2     0.0   0.0                                       10.620000
# Patient_3     0.0   0.0                                        9.964667
# Patient_4     0.0   0.0                                       11.420000
# Patient_6     0.0   0.0                                       10.140000
# ...           ...   ...                                             ...
# Patient_47    0.0   0.0                                       10.720000
# Patient_228   0.0   0.0                                       10.640000
# Patient_237   0.2   0.0                                        9.354000
# Patient_407   0.0   0.0                                       10.200000
# Patient_463   0.0   0.0                                        9.620000
#
#              days_to_recurrence  d370  c800  Platelets [#/volume] in Blood  \
# Patient_1                 800.6   0.0   0.0                         211.60
# Patient_2                 647.6   0.0   0.0                         201.40
# Patient_3                 372.2   0.0   0.0                         225.00
# Patient_4                 698.2   0.0   0.0                         198.00
# Patient_6                 388.0   0.0   0.0                         274.77
# ...                         ...   ...   ...                            ...
# Patient_47                801.4   0.0   0.0                         224.60
# Patient_228               892.8   0.0   0.0                         190.00
# Patient_237               453.6   0.0   0.0                         326.20
# Patient_407               748.2   0.2   0.0                         343.00
# Patient_463               940.4   0.0   0.0                         275.17
#
#              c322  survival_status  Eosinophils [#/volume] in Blood  ...  \
# Patient_1     0.0              1.0                         0.160333  ...
# Patient_2     0.0              1.0                         0.110000  ...
# Patient_3     0.0              1.0                         0.076000  ...
# Patient_4     0.0              0.8                         0.100833  ...
# Patient_6     0.0              1.0                         0.130000  ...
# ...           ...              ...                              ...  ...
# Patient_47    0.0              1.0                         0.180000  ...
# Patient_228   0.0              0.0                         0.098167  ...
# Patient_237   0.0              1.0                         0.080000  ...
# Patient_407   0.0              1.0                         0.126000  ...
# Patient_463   0.0              0.0                         0.174167  ...
#
#              Basophils [#/volume] in Blood  days_to_last_information  c132  \
# Patient_1                           0.0244                    2258.0   0.0
# Patient_2                           0.0300                    1625.2   0.0
# Patient_3                           0.0422                    2290.0   0.0
# Patient_4                           0.0260                    2996.0   0.0
# Patient_6                           0.0300                    2286.2   0.0
# ...                                    ...                       ...   ...
# Patient_47                          0.0240                    1162.8   0.0
# Patient_228                         0.0340                      29.0   0.0
# Patient_237                         0.0242                     212.0   0.0
# Patient_407                         0.0320                    1700.4   0.0
# Patient_463                         0.0222                    1195.4   0.0
#
#              c099  \
# Patient_1     0.0
# Patient_2     0.0
# Patient_3     0.0
# Patient_4     0.0
# Patient_6     0.0
# ...           ...
# Patient_47    0.0
# Patient_228   0.0
# Patient_237   0.0
# Patient_407   0.0
# Patient_463   0.0
#
#              Erythrocyte mean corpuscular hemoglobin concentration [Mass/volume]  \
# Patient_1                                            34.480000
# Patient_2                                            35.400002
# Patient_3                                            34.700001
# Patient_4                                            34.500000
# Patient_6                                            35.500000
# ...                                                        ...
# Patient_47                                           35.140001
# Patient_228                                          33.939999
# Patient_237                                          34.860000
# Patient_407                                          34.180000
# Patient_463                                          33.980000
#
#              c022  lymphovascular_invasion_L  c328  days_to_rfs_event  c020
# Patient_1     0.0                        0.4   0.0              994.4   0.0
# Patient_2     0.0                        0.0   0.0              341.0   0.0
# Patient_3     0.0                        0.2   0.0              908.8   0.0
# Patient_4     0.0                        0.0   0.0             2440.0   0.0
# Patient_6     0.0                        0.4   0.0             1867.2   0.0
# ...           ...                        ...   ...                ...   ...
# Patient_47    0.0                        1.0   0.4             4204.0   0.0
# Patient_228   0.2                        0.0   0.0              252.0   0.0
# Patient_237   0.0                        0.0   0.2             1149.0   0.0
# Patient_407   0.0                        0.2   0.0              465.2   0.0
# Patient_463   0.2                        0.2   0.2              917.0   0.0
#
# [763 rows x 71 columns]
#              c028  Platelet mean volume [Entitic volume] in Blood  \
# Patient_1     0.0                                       10.300000
# Patient_2     0.0                                       10.100000
# Patient_3     0.0                                       10.420000
# Patient_4     0.0                                       10.523334
# Patient_6     0.0                                       10.200000
# ...           ...                                             ...
# Patient_47    0.0                                       10.580000
# Patient_228   0.0                                        9.880000
# Patient_237   0.0                                       10.420000
# Patient_407   0.0                                       10.720000
# Patient_463   0.0                                       10.560000
#
#              days_to_recurrence  d370  c800  Platelets [#/volume] in Blood  \
# Patient_1                 619.4   0.0   0.0                          156.0
# Patient_2                 357.0   0.0   0.0                          295.0
# Patient_3                 534.4   0.0   0.0                          225.0
# Patient_4                 882.4   1.0   0.0                          198.0
# Patient_6                 459.0   0.0   0.0                          217.0
# ...                         ...   ...   ...                            ...
# Patient_47                590.8   0.0   0.0                          261.6
# Patient_228               230.0   0.0   0.0                          245.8
# Patient_237               190.6   0.0   0.0                          255.0
# Patient_407               333.2   0.0   0.0                          230.6
# Patient_463               468.0   0.2   0.0                          275.6
#
#              c322  survival_status  Eosinophils [#/volume] in Blood  c098  \
# Patient_1     0.0              1.0                         0.060000   0.0
# Patient_2     0.0              1.0                         0.110000   0.0
# Patient_3     0.0              1.0                         0.136000   0.0
# Patient_4     0.0              1.0                         0.100833   0.0
# Patient_6     0.0              1.0                         0.130000   0.0
# ...           ...              ...                              ...   ...
# Patient_47    0.0              0.8                         0.150000   0.2
# Patient_228   0.0              0.0                         0.140000   0.2
# Patient_237   0.0              1.0                         0.136000   0.2
# Patient_407   0.0              1.0                         0.128000   0.4
# Patient_463   0.0              0.0                         0.120167   0.2
#
#              ...  Basophils [#/volume] in Blood  days_to_last_information  \
# Patient_1    ...                          0.020                    2258.0
# Patient_2    ...                          0.030                    1753.0
# Patient_3    ...                          0.010                     851.0
# Patient_4    ...                          0.021                    2996.0
# Patient_6    ...                          0.042                     991.0
# ...          ...                            ...                       ...
# Patient_47   ...                          0.046                    4228.0
# Patient_228  ...                          0.050                      29.0
# Patient_237  ...                          0.044                     212.0
# Patient_407  ...                          0.040                    1220.0
# Patient_463  ...                          0.040                     939.0
#
#              c132  c099  \
# Patient_1     0.0   0.0
# Patient_2     0.0   0.0
# Patient_3     0.0   0.0
# Patient_4     0.0   0.0
# Patient_6     0.0   0.0
# ...           ...   ...
# Patient_47    0.0   0.0
# Patient_228   0.0   0.0
# Patient_237   0.0   0.0
# Patient_407   0.0   0.0
# Patient_463   0.0   0.0
#
#              Erythrocyte mean corpuscular hemoglobin concentration [Mass/volume]  \
# Patient_1                                            35.500000
# Patient_2                                            35.400002
# Patient_3                                            35.099998
# Patient_4                                            34.480000
# Patient_6                                            35.500000
# ...                                                        ...
# Patient_47                                           34.699999
# Patient_228                                          33.760001
# Patient_237                                          34.280000
# Patient_407                                          34.660000
# Patient_463                                          34.540000
#
#              c022  lymphovascular_invasion_L  c328  days_to_rfs_event  c020
# Patient_1     0.0                        1.0   0.0             2230.0   0.0
# Patient_2     0.0                        1.0   0.0             1493.4   0.0
# Patient_3     0.0                        0.0   0.0              831.0   0.0
# Patient_4     0.0                        0.0   0.0             1878.6   0.0
# Patient_6     0.0                        0.0   0.0             1159.8   0.0
# ...           ...                        ...   ...                ...   ...
# Patient_47    0.0                        1.0   0.2             1261.2   0.0
# Patient_228   0.0                        0.4   0.0                6.0   0.0
# Patient_237   0.0                        0.2   0.2              170.0   0.0
# Patient_407   0.0                        0.2   0.2             1261.2   0.0
# Patient_463   0.0                        0.0   0.0              917.0   0.0
#
# [763 rows x 69 columns]
#              c068  c028  Platelet mean volume [Entitic volume] in Blood  \
# Patient_1     0.0   0.0                                       10.300000
# Patient_2     0.0   0.0                                       10.100000
# Patient_3     0.0   0.0                                        8.900000
# Patient_4     0.0   0.0                                       10.523334
# Patient_6     0.0   0.0                                       10.200000
# ...           ...   ...                                             ...
# Patient_47    0.0   0.0                                       10.920000
# Patient_228   0.0   0.0                                       10.289333
# Patient_237   0.0   0.0                                       10.124667
# Patient_407   0.0   0.0                                       10.684667
# Patient_463   0.0   0.0                                       10.544667
#
#              days_to_recurrence  d370  c800  Platelets [#/volume] in Blood  \
# Patient_1                 916.2   0.0   0.0                          156.0
# Patient_2                 357.0   0.0   0.0                          244.6
# Patient_3                 635.2   0.0   0.0                          225.0
# Patient_4                1014.6   0.0   0.0                          198.0
# Patient_6                 638.0   0.0   0.0                          217.0
# ...                         ...   ...   ...                            ...
# Patient_47                375.4   0.0   0.0                          211.4
# Patient_228               194.4   0.0   0.0                          248.8
# Patient_237               162.0   0.0   0.0                          241.0
# Patient_407               978.8   0.0   0.0                          268.8
# Patient_463               732.2   0.0   0.0                          291.2
#
#              c322  survival_status  Eosinophils [#/volume] in Blood  ...  \
# Patient_1     0.0              1.0                         0.060000  ...
# Patient_2     0.0              1.0                         0.268000  ...
# Patient_3     0.0              1.0                         0.010000  ...
# Patient_4     0.0              1.0                         0.100833  ...
# Patient_6     0.0              1.0                         0.130000  ...
# ...           ...              ...                              ...  ...
# Patient_47    0.0              1.0                         0.160000  ...
# Patient_228   0.0              0.0                         0.130000  ...
# Patient_237   0.0              1.0                         0.150000  ...
# Patient_407   0.0              1.0                         0.092000  ...
# Patient_463   0.0              0.6                         0.148000  ...
#
#              Basophils [#/volume] in Blood  days_to_last_information  c132  \
# Patient_1                            0.020                    1906.6   0.0
# Patient_2                            0.030                    1753.0   0.0
# Patient_3                            0.018                     851.0   0.0
# Patient_4                            0.021                    2996.0   0.0
# Patient_6                            0.030                     991.0   0.0
# ...                                    ...                       ...   ...
# Patient_47                           0.046                    1995.6   0.0
# Patient_228                          0.030                      29.0   0.0
# Patient_237                          0.036                     212.0   0.0
# Patient_407                          0.024                    1220.0   0.0
# Patient_463                          0.048                     939.0   0.0
#
#              c099  \
# Patient_1     0.0
# Patient_2     0.0
# Patient_3     0.0
# Patient_4     0.0
# Patient_6     0.0
# ...           ...
# Patient_47    0.0
# Patient_228   0.0
# Patient_237   0.0
# Patient_407   0.0
# Patient_463   0.0
#
#              Erythrocyte mean corpuscular hemoglobin concentration [Mass/volume]  \
# Patient_1                                            35.500000
# Patient_2                                            35.400002
# Patient_3                                            35.099998
# Patient_4                                            33.300000
# Patient_6                                            35.500000
# ...                                                        ...
# Patient_47                                           34.440000
# Patient_228                                          34.580000
# Patient_237                                          34.320000
# Patient_407                                          33.820000
# Patient_463                                          34.739999
#
#              c022  lymphovascular_invasion_L  c328  days_to_rfs_event  c020
# Patient_1     0.0                        0.4   0.0             2230.0   0.0
# Patient_2     0.0                        1.0   0.0              341.0   0.0
# Patient_3     0.0                        0.0   0.0              831.0   0.0
# Patient_4     0.0                        0.0   0.0             2982.0   0.0
# Patient_6     0.0                        0.0   0.0              943.0   0.0
# ...           ...                        ...   ...                ...   ...
# Patient_47    0.0                        1.0   0.2             4204.0   0.0
# Patient_228   0.0                        0.2   0.0                6.0   0.0
# Patient_237   0.2                        0.0   0.0              170.0   0.0
# Patient_407   0.0                        0.4   0.0             1199.0   0.0
# Patient_463   0.0                        0.0   0.0              917.0   0.0
#
# [763 rows x 70 columns]
#              c068  c028  Platelet mean volume [Entitic volume] in Blood  \
# Patient_1     0.0   0.0                                        9.980000
# Patient_2     0.0   0.0                                       10.860000
# Patient_3     0.0   0.0                                       11.084667
# Patient_4     0.0   0.0                                       10.464667
# Patient_6     0.0   0.0                                       10.469333
# ...           ...   ...                                             ...
# Patient_47    0.0   0.0                                       10.744667
# Patient_228   0.0   0.0                                       11.800000
# Patient_237   0.0   0.0                                       11.360000
# Patient_407   0.0   0.0                                       10.824667
# Patient_463   0.0   0.0                                       10.324667
#
#              days_to_recurrence  d370  c800  Platelets [#/volume] in Blood  \
# Patient_1                 595.0   0.2   0.0                          156.0
# Patient_2                 357.0   0.0   0.0                          252.2
# Patient_3                 580.4   0.2   0.0                          224.2
# Patient_4                1240.4   0.0   0.0                          237.8
# Patient_6                 441.6   0.0   0.0                          217.0
# ...                         ...   ...   ...                            ...
# Patient_47                804.6   0.2   0.0                          205.8
# Patient_228               507.6   0.2   0.0                          288.4
# Patient_237               425.4   0.0   0.0                          256.4
# Patient_407               794.6   0.0   0.0                          242.4
# Patient_463               823.6   0.2   0.0                          288.2
#
#              c322  survival_status  Eosinophils [#/volume] in Blood  ...  \
# Patient_1     0.0              1.0                         0.098000  ...
# Patient_2     0.0              0.2                         0.110000  ...
# Patient_3     0.0              0.6                         0.108000  ...
# Patient_4     0.0              1.0                         0.154167  ...
# Patient_6     0.0              1.0                         0.216000  ...
# ...           ...              ...                              ...  ...
# Patient_47    0.0              1.0                         0.152167  ...
# Patient_228   0.0              0.4                         0.140000  ...
# Patient_237   0.0              1.0                         0.150000  ...
# Patient_407   0.0              0.8                         0.134167  ...
# Patient_463   0.0              0.0                         0.146167  ...
#
#              Basophils [#/volume] in Blood  days_to_last_information  c132  \
# Patient_1                           0.0200                    2021.8   0.0
# Patient_2                           0.0262                    1620.2   0.0
# Patient_3                           0.0100                     851.0   0.0
# Patient_4                           0.0284                    1819.0   0.0
# Patient_6                           0.0300                     991.0   0.0
# ...                                    ...                       ...   ...
# Patient_47                          0.0400                    1596.8   0.0
# Patient_228                         0.0340                    1375.2   0.0
# Patient_237                         0.0300                     922.0   0.0
# Patient_407                         0.0340                    1179.6   0.0
# Patient_463                         0.0262                     939.0   0.0
#
#              c099  \
# Patient_1     0.0
# Patient_2     0.2
# Patient_3     0.2
# Patient_4     0.0
# Patient_6     0.0
# ...           ...
# Patient_47    0.0
# Patient_228   0.0
# Patient_237   0.0
# Patient_407   0.0
# Patient_463   0.0
#
#              Erythrocyte mean corpuscular hemoglobin concentration [Mass/volume]  \
# Patient_1                                            33.860000
# Patient_2                                            35.400002
# Patient_3                                            34.320001
# Patient_4                                            34.399999
# Patient_6                                            35.500000
# ...                                                        ...
# Patient_47                                           34.380000
# Patient_228                                          34.560000
# Patient_237                                          33.580000
# Patient_407                                          33.220001
# Patient_463                                          34.400000
#
#              c022  lymphovascular_invasion_L  c328  days_to_rfs_event  c020
# Patient_1     0.0                        1.0   0.0             3351.0   0.0
# Patient_2     0.0                        1.0   0.0              341.0   0.0
# Patient_3     0.0                        0.2   0.0              831.0   0.0
# Patient_4     0.0                        0.0   0.0             2341.6   0.0
# Patient_6     0.0                        0.2   0.0              943.0   0.0
# ...           ...                        ...   ...                ...   ...
# Patient_47    0.0                        1.0   0.0             4204.0   0.0
# Patient_228   0.0                        0.0   0.0             1564.0   0.0
# Patient_237   0.0                        0.0   0.0              518.0   0.0
# Patient_407   0.0                        0.0   0.2              576.4   0.0
# Patient_463   0.0                        0.0   0.2              917.0   0.0
#
# [763 rows x 70 columns]
#              c028  Platelet mean volume [Entitic volume] in Blood  \
# Patient_1     0.0                                       10.300000
# Patient_2     0.0                                       10.100000
# Patient_3     0.0                                        8.900000
# Patient_4     0.0                                       10.523334
# Patient_6     0.0                                       10.200000
# ...           ...                                             ...
# Patient_47    0.0                                       10.434000
# Patient_228   0.0                                       10.244667
# Patient_237   0.0                                       10.200000
# Patient_407   0.0                                       10.760000
# Patient_463   0.0                                       10.460000
#
#              days_to_recurrence  d370  c800  Platelets [#/volume] in Blood  \
# Patient_1                 345.4   0.0   0.0                         156.00
# Patient_2                 357.0   0.0   0.0                         295.00
# Patient_3                 444.6   0.0   0.0                         225.00
# Patient_4                2155.0   1.0   0.0                         198.00
# Patient_6                 826.4   0.0   0.0                         217.00
# ...                         ...   ...   ...                            ...
# Patient_47               1746.0   0.0   0.2                         289.97
# Patient_228               181.6   0.0   0.0                         262.40
# Patient_237               179.0   0.0   0.2                         261.60
# Patient_407               397.0   0.0   0.0                         284.00
# Patient_463               691.0   0.2   0.0                         242.60
#
#              c322  survival_status  Eosinophils [#/volume] in Blood  c098  \
# Patient_1     0.0              1.0                         0.060000   0.0
# Patient_2     0.0              1.0                         0.110000   0.0
# Patient_3     0.0              1.0                         0.010000   0.0
# Patient_4     0.0              1.0                         0.100833   0.0
# Patient_6     0.0              1.0                         0.130000   0.0
# ...           ...              ...                              ...   ...
# Patient_47    0.0              1.0                         0.108333   0.2
# Patient_228   0.0              0.0                         0.054000   0.2
# Patient_237   0.0              1.0                         0.108000   0.0
# Patient_407   0.0              1.0                         0.108000   0.4
# Patient_463   0.0              0.0                         0.182000   0.2
#
#              ...  Basophils [#/volume] in Blood  days_to_last_information  \
# Patient_1    ...                         0.0200                    2258.0
# Patient_2    ...                         0.0300                    1753.0
# Patient_3    ...                         0.0100                     851.0
# Patient_4    ...                         0.0210                    2996.0
# Patient_6    ...                         0.0300                     991.0
# ...          ...                            ...                       ...
# Patient_47   ...                         0.0244                    4228.0
# Patient_228  ...                         0.0300                      29.0
# Patient_237  ...                         0.0440                     212.0
# Patient_407  ...                         0.0240                    1220.0
# Patient_463  ...                         0.0320                     939.0
#
#              c132  c099  \
# Patient_1     0.0   0.0
# Patient_2     0.0   0.0
# Patient_3     0.0   0.0
# Patient_4     0.0   0.0
# Patient_6     0.0   0.0
# ...           ...   ...
# Patient_47    0.0   0.0
# Patient_228   0.2   0.0
# Patient_237   0.0   0.0
# Patient_407   0.0   0.0
# Patient_463   0.0   0.0
#
#              Erythrocyte mean corpuscular hemoglobin concentration [Mass/volume]  \
# Patient_1                                            35.500000
# Patient_2                                            35.400002
# Patient_3                                            35.099998
# Patient_4                                            33.300000
# Patient_6                                            35.500000
# ...                                                        ...
# Patient_47                                           34.663000
# Patient_228                                          33.460000
# Patient_237                                          34.140000
# Patient_407                                          34.720000
# Patient_463                                          34.040000
#
#              c022  lymphovascular_invasion_L  c328  days_to_rfs_event  c020
# Patient_1     0.0                        1.0   0.0             2230.0   0.0
# Patient_2     0.0                        1.0   0.0              341.0   0.0
# Patient_3     0.0                        0.0   0.0              831.0   0.0
# Patient_4     0.0                        0.0   0.0             2982.0   0.0
# Patient_6     0.0                        0.0   0.0              943.0   0.0
# ...           ...                        ...   ...                ...   ...
# Patient_47    0.0                        1.0   0.0             4204.0   0.0
# Patient_228   0.0                        0.0   0.0                6.0   0.0
# Patient_237   0.0                        0.0   0.2              170.0   0.0
# Patient_407   0.0                        0.2   0.2             1199.0   0.0
# Patient_463   0.0                        0.0   0.2              917.0   0.0
#
# [763 rows x 69 columns]
#              c068  c028  Platelet mean volume [Entitic volume] in Blood  \
# Patient_1     0.0   0.0                                       10.300000
# Patient_2     0.0   0.0                                       11.104667
# Patient_3     0.0   0.0                                       10.760000
# Patient_4     0.0   0.0                                       10.523334
# Patient_6     0.0   0.0                                       10.680000
# ...           ...   ...                                             ...
# Patient_47    0.0   0.0                                       10.204667
# Patient_228   0.0   0.0                                       10.449334
# Patient_237   0.0   0.0                                       11.340000
# Patient_407   0.0   0.0                                       10.260000
# Patient_463   0.0   0.0                                       10.360000
#
#              days_to_recurrence  d370  c800  Platelets [#/volume] in Blood  \
# Patient_1                 908.6   0.0   0.0                          249.8
# Patient_2                 357.0   0.0   0.0                          267.0
# Patient_3                 397.8   0.0   0.2                          225.0
# Patient_4                 432.6   0.0   0.0                          198.0
# Patient_6                 480.8   0.0   0.0                          217.0
# ...                         ...   ...   ...                            ...
# Patient_47                724.6   0.0   0.2                          245.0
# Patient_228               807.2   0.0   0.0                          260.6
# Patient_237               731.4   0.0   0.0                          277.4
# Patient_407               963.2   0.0   0.2                          278.2
# Patient_463               205.6   0.0   0.0                          260.2
#
#              c322  survival_status  Eosinophils [#/volume] in Blood  ...  \
# Patient_1     0.0              0.8                         0.060000  ...
# Patient_2     0.0              0.8                         0.110000  ...
# Patient_3     0.0              1.0                         0.010000  ...
# Patient_4     0.0              1.0                         0.100833  ...
# Patient_6     0.0              1.0                         0.098000  ...
# ...           ...              ...                              ...  ...
# Patient_47    0.0              1.0                         0.126000  ...
# Patient_228   0.0              0.0                         0.108167  ...
# Patient_237   0.0              0.6                         0.162000  ...
# Patient_407   0.0              1.0                         0.132167  ...
# Patient_463   0.0              0.0                         0.116000  ...
#
#              Basophils [#/volume] in Blood  days_to_last_information  c132  \
# Patient_1                           0.0200                    2258.0   0.2
# Patient_2                           0.0300                    1753.0   0.0
# Patient_3                           0.0200                     851.0   0.0
# Patient_4                           0.0210                    2066.4   0.0
# Patient_6                           0.0260                     991.0   0.0
# ...                                    ...                       ...   ...
# Patient_47                          0.0340                    2678.4   0.0
# Patient_228                         0.0322                      29.0   0.0
# Patient_237                         0.0400                    1643.2   0.0
# Patient_407                         0.0360                    1220.0   0.0
# Patient_463                         0.0360                     939.0   0.0
#
#              c099  \
# Patient_1     0.0
# Patient_2     0.0
# Patient_3     0.0
# Patient_4     0.0
# Patient_6     0.0
# ...           ...
# Patient_47    0.0
# Patient_228   0.0
# Patient_237   0.0
# Patient_407   0.0
# Patient_463   0.0
#
#              Erythrocyte mean corpuscular hemoglobin concentration [Mass/volume]  \
# Patient_1                                            34.239999
# Patient_2                                            35.400002
# Patient_3                                            34.460000
# Patient_4                                            34.663000
# Patient_6                                            35.500000
# ...                                                        ...
# Patient_47                                           34.180000
# Patient_228                                          34.500000
# Patient_237                                          33.879999
# Patient_407                                          34.420000
# Patient_463                                          34.259999
#
#              c022  lymphovascular_invasion_L  c328  days_to_rfs_event  c020
# Patient_1     0.0                        0.2   0.0              912.8   0.0
# Patient_2     0.0                        0.2   0.2             2653.2   0.0
# Patient_3     0.0                        0.2   0.0             1455.2   0.0
# Patient_4     0.0                        0.0   0.0             1155.2   0.0
# Patient_6     0.0                        0.0   0.2              943.0   0.0
# ...           ...                        ...   ...                ...   ...
# Patient_47    0.0                        1.0   0.0             4204.0   0.0
# Patient_228   0.0                        0.0   0.2                6.0   0.0
# Patient_237   0.0                        0.0   0.2              170.0   0.0
# Patient_407   0.0                        0.0   0.0             1517.2   0.0
# Patient_463   0.0                        0.0   0.4              917.0   0.0
#
# [763 rows x 70 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 36
#      33             trafo_df.loc[sample, var] = max_category
#      34         else:
#      35             # Set already existing value into aggregated dataframe.
# ---> 36             trafo_df.loc[sample, var] = simulated_df.loc[sample, var]
#      38 print(imputed_df[list(non_ohe_cols)])
#      39 # Combine imputed df with ohe-transformed imputed df.
#      40 #final_df = pd.concat([imputed_df[list(non_ohe_cols)], trafo_df], axis=1)
#      41 #target_file = target_dir / str(imputed_file).split("/")[1]
#      42 #final_df.to_csv(target_file, sep='\t', index=True)
#
# File ~/miniforge3/envs/work/lib/python3.11/site-packages/pandas/core/indexing.py:1181, in _LocationIndexer.__getitem__(self, key)
#    1179 if type(key) is tuple:
#    1180     key = tuple(list(x) if is_iterator(x) else x for x in key)
# -> 1181     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
#
# File ~/miniforge3/envs/work/lib/python3.11/site-packages/pandas/core/indexing.py:1181, in <genexpr>(.0)
#    1179 if type(key) is tuple:
#    1180     key = tuple(list(x) if is_iterator(x) else x for x in key)
# -> 1181     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
#
# File ~/miniforge3/envs/work/lib/python3.11/site-packages/pandas/core/common.py:372, in apply_if_callable(maybe_callable, obj, **kwargs)
#     365     # everything failed (probably because the argument
#     366     # wasn't actually callable); we return None
#     367     # instead of the empty string in this case to allow
#     368     # distinguishing between no name and a name of ''
#     369     return None
# --> 372 def apply_if_callable(maybe_callable, obj, **kwargs):
#     373     """
#     374     Evaluate possibly callable input using obj and kwargs if it is callable,
#     375     otherwise return as it is.
#    (...)
#     381     **kwargs
#     382     """
#     383     if callable(maybe_callable):
#
# KeyboardInterrupt:
