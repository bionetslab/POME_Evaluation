# %%
import pandas as pd
import glob
from pathlib import Path

# %%
imputed_dir = Path("imputed_ohe_data")
simulated_dir = Path("simulated_data")
target_dir = Path("imputed_data")

# %%
for imputed_file in imputed_dir.glob("*.tsv"):
    # Build corresponding csv path with same stem (filename without extension)
    simulated_file = simulated_dir / str(imputed_file).split("/")[1]
    
    imputed_df = pd.read_csv(imputed_file, sep="\t", index_col=0)
    
    simulated_df = pd.read_csv(simulated_file, sep="\t", index_col=0)
    simulated_df.drop(columns=['type'], inplace=True)
    simulated_df = simulated_df.T.copy()
    simulated_df.replace({-99.0 : pd.NA}, inplace=True)
    
    # Subset to OHE variables.
    ohe_cols = [col for col in imputed_df.columns if col.startswith("ohe")]
    print(ohe_cols)
    non_ohe_cols = set(imputed_df.columns) - set(ohe_cols)
    ohe_df = imputed_df[ohe_cols].copy()
    
    ohe_vars = [col[4:] for col in ohe_cols]
    ohe_vars = set([var.rsplit('_', 1)[0] for var in ohe_vars])
    print(ohe_vars)
    var_to_columns = {var : [col for col in ohe_cols if (var in col)] for var in ohe_vars}
    print(var_to_columns)
    
    trafo_df = pd.DataFrame(index=ohe_df.index, columns=list(ohe_vars))

    # Iterate over all OHE variables and choose maximum imputed value as category.
    for var in ohe_vars:
        for sample in trafo_df.index:
            # Check if sample-var pair has been NA in input data.
            if pd.isna(simulated_df.loc[sample, var]):
                # Search max value in OHE imputed file.
                var_categories = var_to_columns[var]
                col_values = {col : imputed_df.at[sample, col] for col in var_categories}
                max_col = max(col_values, key=col_values.get)
                max_category = float(max_col[-3:])
                # Set best category into imputed dataframe.
                trafo_df.loc[sample, var] = max_category
            else:
                # Set already existing value into aggregated dataframe.
                trafo_df.loc[sample, var] = simulated_df.loc[sample, var]

    # Combine imputed df with ohe-transformed imputed df.
    final_df = pd.concat([imputed_df[list(non_ohe_cols)], trafo_df], axis=1)
    target_file = target_dir / str(imputed_file).split("/")[1]
    final_df.to_csv(target_file, sep='\t', index=True)
# Out:
# ['ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_0.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_1.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_2.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_3.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_4.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_5.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_6.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_7.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_8.0', 'ohe_American Joint Committee on Cancer Publication Version Type_0.0', 'ohe_American Joint Committee on Cancer Publication Version Type_1.0', 'ohe_American Joint Committee on Cancer Publication Version Type_2.0', 'ohe_American Joint Committee on Cancer Publication Version Type_3.0', 'ohe_American Joint Committee on Cancer Publication Version Type_4.0', 'ohe_Center of sequencing_0.0', 'ohe_Center of sequencing_1.0', 'ohe_Center of sequencing_2.0', 'ohe_Center of sequencing_3.0', 'ohe_Center of sequencing_4.0', 'ohe_Center of sequencing_5.0', 'ohe_Center of sequencing_6.0', 'ohe_Center of sequencing_7.0', 'ohe_Center of sequencing_8.0', 'ohe_Center of sequencing_9.0', 'ohe_Center of sequencing_10.0', 'ohe_Center of sequencing_11.0', 'ohe_Center of sequencing_12.0', 'ohe_Center of sequencing_13.0', 'ohe_Center of sequencing_14.0', 'ohe_Center of sequencing_15.0', 'ohe_Center of sequencing_16.0', 'ohe_Center of sequencing_17.0', 'ohe_Center of sequencing_18.0', 'ohe_Center of sequencing_19.0', 'ohe_Center of sequencing_20.0', 'ohe_Center of sequencing_21.0', 'ohe_Center of sequencing_22.0', 'ohe_Center of sequencing_23.0', 'ohe_Center of sequencing_24.0', 'ohe_Center of sequencing_25.0', 'ohe_Center of sequencing_26.0', 'ohe_Center of sequencing_27.0', 'ohe_Center of sequencing_28.0', 'ohe_Center of sequencing_29.0', 'ohe_Center of sequencing_30.0', 'ohe_Center of sequencing_31.0', 'ohe_Center of sequencing_32.0', 'ohe_Center of sequencing_33.0', 'ohe_Form completion date_0.0', 'ohe_Form completion date_1.0', 'ohe_Form completion date_2.0', 'ohe_Form completion date_3.0', 'ohe_Form completion date_4.0', 'ohe_Form completion date_5.0', 'ohe_Form completion date_6.0', 'ohe_Form completion date_7.0', 'ohe_Form completion date_8.0', 'ohe_Form completion date_9.0', 'ohe_Form completion date_10.0', 'ohe_Form completion date_11.0', 'ohe_Form completion date_12.0', 'ohe_Form completion date_13.0', 'ohe_Form completion date_14.0', 'ohe_Form completion date_15.0', 'ohe_Form completion date_16.0', 'ohe_Form completion date_17.0', 'ohe_Form completion date_18.0', 'ohe_Form completion date_19.0', 'ohe_Form completion date_20.0', 'ohe_Form completion date_21.0', 'ohe_Form completion date_22.0', 'ohe_Form completion date_23.0', 'ohe_Form completion date_24.0', 'ohe_Form completion date_26.0', 'ohe_Form completion date_27.0', 'ohe_Form completion date_28.0', 'ohe_Form completion date_29.0', 'ohe_Form completion date_30.0', 'ohe_Form completion date_31.0', 'ohe_Form completion date_32.0', 'ohe_Form completion date_33.0', 'ohe_Form completion date_34.0', 'ohe_Form completion date_35.0', 'ohe_Form completion date_36.0', 'ohe_Form completion date_37.0', 'ohe_Form completion date_38.0', 'ohe_Form completion date_39.0', 'ohe_Form completion date_40.0', 'ohe_Form completion date_41.0', 'ohe_Form completion date_42.0', 'ohe_Form completion date_43.0', 'ohe_Form completion date_44.0', 'ohe_Form completion date_45.0', 'ohe_Form completion date_46.0', 'ohe_Form completion date_47.0', 'ohe_Form completion date_48.0', 'ohe_Form completion date_49.0', 'ohe_Form completion date_50.0', 'ohe_Form completion date_51.0', 'ohe_Form completion date_52.0', 'ohe_Form completion date_53.0', 'ohe_Form completion date_54.0', 'ohe_Form completion date_55.0', 'ohe_Form completion date_56.0', 'ohe_Form completion date_57 ...
# {'1q Status', '18q Status', '19p Status', '21 (21q) Status', 'Form completion date', 'ICD-10 Classification', '12q Status', '8p Status', 'Neoplasm Disease Lymph Node Stage American Joint Committee on Cancer Code', '12p Status', '20q Status', '3p Status', 'International Classification of Diseases for Oncology, Third Edition ICD-O-3 Histology Code', '19q Status', '14 (14q) Status', '2q Status', '16q Status', '6q Status', 'American Joint Committee on Cancer Metastasis Stage Code', '11p Status', '2p Status', '17p Status', '20p Status', '22 (22q) Status', 'Other Patient ID', '3q Status', '4q Status', 'American Joint Committee on Cancer Publication Version Type', 'Neoplasm Disease Stage American Joint Committee on Cancer Code', '18p Status', '6p Status', 'Tissue Source Site', 'American Joint Committee on Cancer Tumor Stage Code', '10p Status', '9q Status', '4p Status', '9p Status', 'Prior Diagnosis', '1p Status', '5p Status', '5q Status', 'Center of sequencing', 'International Classification of Diseases for Oncology, Third Edition ICD-O-3 Site Code', '15 (15q) Status', '17q Status', '7q Status', '8q Status', 'Tumor Type', '10q Status', 'Race Category', '11q Status', '7p Status', '16p Status', '13 (13q) Status'}
# {'1q Status': ['ohe_11q Status_0.0', 'ohe_11q Status_1.0', 'ohe_11q Status_2.0', 'ohe_1q Status_0.0', 'ohe_1q Status_1.0', 'ohe_1q Status_2.0'], '18q Status': ['ohe_18q Status_0.0', 'ohe_18q Status_1.0', 'ohe_18q Status_2.0'], '19p Status': ['ohe_19p Status_0.0', 'ohe_19p Status_1.0', 'ohe_19p Status_2.0'], '21 (21q) Status': ['ohe_21 (21q) Status_0.0', 'ohe_21 (21q) Status_1.0', 'ohe_21 (21q) Status_2.0'], 'Form completion date': ['ohe_Form completion date_0.0', 'ohe_Form completion date_1.0', 'ohe_Form completion date_2.0', 'ohe_Form completion date_3.0', 'ohe_Form completion date_4.0', 'ohe_Form completion date_5.0', 'ohe_Form completion date_6.0', 'ohe_Form completion date_7.0', 'ohe_Form completion date_8.0', 'ohe_Form completion date_9.0', 'ohe_Form completion date_10.0', 'ohe_Form completion date_11.0', 'ohe_Form completion date_12.0', 'ohe_Form completion date_13.0', 'ohe_Form completion date_14.0', 'ohe_Form completion date_15.0', 'ohe_Form completion date_16.0', 'ohe_Form completion date_17.0', 'ohe_Form completion date_18.0', 'ohe_Form completion date_19.0', 'ohe_Form completion date_20.0', 'ohe_Form completion date_21.0', 'ohe_Form completion date_22.0', 'ohe_Form completion date_23.0', 'ohe_Form completion date_24.0', 'ohe_Form completion date_26.0', 'ohe_Form completion date_27.0', 'ohe_Form completion date_28.0', 'ohe_Form completion date_29.0', 'ohe_Form completion date_30.0', 'ohe_Form completion date_31.0', 'ohe_Form completion date_32.0', 'ohe_Form completion date_33.0', 'ohe_Form completion date_34.0', 'ohe_Form completion date_35.0', 'ohe_Form completion date_36.0', 'ohe_Form completion date_37.0', 'ohe_Form completion date_38.0', 'ohe_Form completion date_39.0', 'ohe_Form completion date_40.0', 'ohe_Form completion date_41.0', 'ohe_Form completion date_42.0', 'ohe_Form completion date_43.0', 'ohe_Form completion date_44.0', 'ohe_Form completion date_45.0', 'ohe_Form completion date_46.0', 'ohe_Form completion date_47.0', 'ohe_Form completion date_48.0', 'ohe_Form completion date_49.0', 'ohe_Form completion date_50.0', 'ohe_Form completion date_51.0', 'ohe_Form completion date_52.0', 'ohe_Form completion date_53.0', 'ohe_Form completion date_54.0', 'ohe_Form completion date_55.0', 'ohe_Form completion date_56.0', 'ohe_Form completion date_57.0', 'ohe_Form completion date_58.0', 'ohe_Form completion date_59.0', 'ohe_Form completion date_60.0', 'ohe_Form completion date_61.0', 'ohe_Form completion date_62.0', 'ohe_Form completion date_63.0', 'ohe_Form completion date_64.0', 'ohe_Form completion date_65.0', 'ohe_Form completion date_66.0', 'ohe_Form completion date_67.0', 'ohe_Form completion date_68.0', 'ohe_Form completion date_69.0', 'ohe_Form completion date_70.0', 'ohe_Form completion date_71.0', 'ohe_Form completion date_72.0', 'ohe_Form completion date_73.0', 'ohe_Form completion date_74.0', 'ohe_Form completion date_75.0', 'ohe_Form completion date_76.0', 'ohe_Form completion date_77.0', 'ohe_Form completion date_78.0', 'ohe_Form completion date_79.0', 'ohe_Form completion date_80.0', 'ohe_Form completion date_81.0', 'ohe_Form completion date_82.0', 'ohe_Form completion date_83.0', 'ohe_Form completion date_84.0', 'ohe_Form completion date_85.0', 'ohe_Form completion date_86.0', 'ohe_Form completion date_87.0', 'ohe_Form completion date_88.0', 'ohe_Form completion date_89.0', 'ohe_Form completion date_90.0', 'ohe_Form completion date_91.0', 'ohe_Form completion date_92.0', 'ohe_Form completion date_93.0', 'ohe_Form completion date_94.0', 'ohe_Form completion date_95.0', 'ohe_Form completion date_96.0', 'ohe_Form completion date_97.0', 'ohe_Form completion date_98.0', 'ohe_Form completion date_99.0', 'ohe_Form completion date_100.0', 'ohe_Form completion date_101.0', 'ohe_Form completion date_102.0', 'ohe_Form completion date_103.0', 'ohe_Form completion date_104.0', 'ohe_Form completion date_105.0', 'ohe_Form completion date_106.0', 'ohe_Form completion date_107.0', 'ohe_Form completion date_108.0', ' ...
# ['ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_0.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_1.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_2.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_4.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_5.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_6.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_7.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_8.0', 'ohe_American Joint Committee on Cancer Publication Version Type_0.0', 'ohe_American Joint Committee on Cancer Publication Version Type_1.0', 'ohe_American Joint Committee on Cancer Publication Version Type_2.0', 'ohe_American Joint Committee on Cancer Publication Version Type_3.0', 'ohe_American Joint Committee on Cancer Publication Version Type_4.0', 'ohe_Center of sequencing_0.0', 'ohe_Center of sequencing_1.0', 'ohe_Center of sequencing_3.0', 'ohe_Center of sequencing_4.0', 'ohe_Center of sequencing_5.0', 'ohe_Center of sequencing_6.0', 'ohe_Center of sequencing_7.0', 'ohe_Center of sequencing_8.0', 'ohe_Center of sequencing_9.0', 'ohe_Center of sequencing_10.0', 'ohe_Center of sequencing_11.0', 'ohe_Center of sequencing_12.0', 'ohe_Center of sequencing_13.0', 'ohe_Center of sequencing_14.0', 'ohe_Center of sequencing_16.0', 'ohe_Center of sequencing_18.0', 'ohe_Center of sequencing_19.0', 'ohe_Center of sequencing_20.0', 'ohe_Center of sequencing_21.0', 'ohe_Center of sequencing_22.0', 'ohe_Center of sequencing_23.0', 'ohe_Center of sequencing_24.0', 'ohe_Center of sequencing_25.0', 'ohe_Center of sequencing_26.0', 'ohe_Center of sequencing_27.0', 'ohe_Center of sequencing_28.0', 'ohe_Center of sequencing_29.0', 'ohe_Center of sequencing_30.0', 'ohe_Center of sequencing_31.0', 'ohe_Center of sequencing_32.0', 'ohe_Center of sequencing_33.0', 'ohe_Form completion date_0.0', 'ohe_Form completion date_1.0', 'ohe_Form completion date_2.0', 'ohe_Form completion date_3.0', 'ohe_Form completion date_5.0', 'ohe_Form completion date_6.0', 'ohe_Form completion date_8.0', 'ohe_Form completion date_10.0', 'ohe_Form completion date_11.0', 'ohe_Form completion date_12.0', 'ohe_Form completion date_13.0', 'ohe_Form completion date_15.0', 'ohe_Form completion date_16.0', 'ohe_Form completion date_17.0', 'ohe_Form completion date_18.0', 'ohe_Form completion date_21.0', 'ohe_Form completion date_22.0', 'ohe_Form completion date_25.0', 'ohe_Form completion date_27.0', 'ohe_Form completion date_29.0', 'ohe_Form completion date_30.0', 'ohe_Form completion date_31.0', 'ohe_Form completion date_32.0', 'ohe_Form completion date_33.0', 'ohe_Form completion date_34.0', 'ohe_Form completion date_36.0', 'ohe_Form completion date_38.0', 'ohe_Form completion date_40.0', 'ohe_Form completion date_41.0', 'ohe_Form completion date_42.0', 'ohe_Form completion date_43.0', 'ohe_Form completion date_44.0', 'ohe_Form completion date_45.0', 'ohe_Form completion date_47.0', 'ohe_Form completion date_49.0', 'ohe_Form completion date_50.0', 'ohe_Form completion date_51.0', 'ohe_Form completion date_52.0', 'ohe_Form completion date_54.0', 'ohe_Form completion date_57.0', 'ohe_Form completion date_58.0', 'ohe_Form completion date_59.0', 'ohe_Form completion date_60.0', 'ohe_Form completion date_63.0', 'ohe_Form completion date_64.0', 'ohe_Form completion date_67.0', 'ohe_Form completion date_68.0', 'ohe_Form completion date_69.0', 'ohe_Form completion date_70.0', 'ohe_Form completion date_71.0', 'ohe_Form completion date_73.0', 'ohe_Form completion date_74.0', 'ohe_Form completion date_76.0', 'ohe_Form completion date_77.0', 'ohe_Form completion date_79.0', 'ohe_Form completion date_80.0', 'ohe_Form completion date_81.0', 'ohe_Form completion date_82.0', 'ohe_Form completion date_83.0', 'ohe_Form completion date_84.0', 'ohe_Form completion date_85.0', 'ohe_Form completion date_86.0', ...
# {'1q Status', '18q Status', '19p Status', '21 (21q) Status', 'Form completion date', 'ICD-10 Classification', '12q Status', '8p Status', 'Neoplasm Disease Lymph Node Stage American Joint Committee on Cancer Code', '12p Status', '20q Status', '3p Status', 'International Classification of Diseases for Oncology, Third Edition ICD-O-3 Histology Code', '19q Status', '14 (14q) Status', '2q Status', '16q Status', '6q Status', 'American Joint Committee on Cancer Metastasis Stage Code', '11p Status', '2p Status', '17p Status', '20p Status', '22 (22q) Status', 'Other Patient ID', '3q Status', '4q Status', 'American Joint Committee on Cancer Publication Version Type', 'Neoplasm Disease Stage American Joint Committee on Cancer Code', '18p Status', '6p Status', 'Tissue Source Site', 'American Joint Committee on Cancer Tumor Stage Code', '10p Status', '9q Status', '4p Status', '9p Status', 'Prior Diagnosis', '1p Status', '5p Status', '5q Status', 'Center of sequencing', 'International Classification of Diseases for Oncology, Third Edition ICD-O-3 Site Code', '15 (15q) Status', '17q Status', '7q Status', '8q Status', 'Tumor Type', '10q Status', 'Race Category', '11q Status', '7p Status', '16p Status', '13 (13q) Status'}
# {'1q Status': ['ohe_11q Status_0.0', 'ohe_11q Status_1.0', 'ohe_11q Status_2.0', 'ohe_1q Status_0.0', 'ohe_1q Status_1.0', 'ohe_1q Status_2.0'], '18q Status': ['ohe_18q Status_0.0', 'ohe_18q Status_1.0', 'ohe_18q Status_2.0'], '19p Status': ['ohe_19p Status_0.0', 'ohe_19p Status_1.0', 'ohe_19p Status_2.0'], '21 (21q) Status': ['ohe_21 (21q) Status_0.0', 'ohe_21 (21q) Status_1.0', 'ohe_21 (21q) Status_2.0'], 'Form completion date': ['ohe_Form completion date_0.0', 'ohe_Form completion date_1.0', 'ohe_Form completion date_2.0', 'ohe_Form completion date_3.0', 'ohe_Form completion date_5.0', 'ohe_Form completion date_6.0', 'ohe_Form completion date_8.0', 'ohe_Form completion date_10.0', 'ohe_Form completion date_11.0', 'ohe_Form completion date_12.0', 'ohe_Form completion date_13.0', 'ohe_Form completion date_15.0', 'ohe_Form completion date_16.0', 'ohe_Form completion date_17.0', 'ohe_Form completion date_18.0', 'ohe_Form completion date_21.0', 'ohe_Form completion date_22.0', 'ohe_Form completion date_25.0', 'ohe_Form completion date_27.0', 'ohe_Form completion date_29.0', 'ohe_Form completion date_30.0', 'ohe_Form completion date_31.0', 'ohe_Form completion date_32.0', 'ohe_Form completion date_33.0', 'ohe_Form completion date_34.0', 'ohe_Form completion date_36.0', 'ohe_Form completion date_38.0', 'ohe_Form completion date_40.0', 'ohe_Form completion date_41.0', 'ohe_Form completion date_42.0', 'ohe_Form completion date_43.0', 'ohe_Form completion date_44.0', 'ohe_Form completion date_45.0', 'ohe_Form completion date_47.0', 'ohe_Form completion date_49.0', 'ohe_Form completion date_50.0', 'ohe_Form completion date_51.0', 'ohe_Form completion date_52.0', 'ohe_Form completion date_54.0', 'ohe_Form completion date_57.0', 'ohe_Form completion date_58.0', 'ohe_Form completion date_59.0', 'ohe_Form completion date_60.0', 'ohe_Form completion date_63.0', 'ohe_Form completion date_64.0', 'ohe_Form completion date_67.0', 'ohe_Form completion date_68.0', 'ohe_Form completion date_69.0', 'ohe_Form completion date_70.0', 'ohe_Form completion date_71.0', 'ohe_Form completion date_73.0', 'ohe_Form completion date_74.0', 'ohe_Form completion date_76.0', 'ohe_Form completion date_77.0', 'ohe_Form completion date_79.0', 'ohe_Form completion date_80.0', 'ohe_Form completion date_81.0', 'ohe_Form completion date_82.0', 'ohe_Form completion date_83.0', 'ohe_Form completion date_84.0', 'ohe_Form completion date_85.0', 'ohe_Form completion date_86.0', 'ohe_Form completion date_87.0', 'ohe_Form completion date_88.0', 'ohe_Form completion date_89.0', 'ohe_Form completion date_94.0', 'ohe_Form completion date_95.0', 'ohe_Form completion date_96.0', 'ohe_Form completion date_97.0', 'ohe_Form completion date_98.0', 'ohe_Form completion date_99.0', 'ohe_Form completion date_101.0', 'ohe_Form completion date_102.0', 'ohe_Form completion date_103.0', 'ohe_Form completion date_104.0', 'ohe_Form completion date_106.0', 'ohe_Form completion date_108.0', 'ohe_Form completion date_109.0', 'ohe_Form completion date_111.0', 'ohe_Form completion date_113.0', 'ohe_Form completion date_114.0', 'ohe_Form completion date_116.0', 'ohe_Form completion date_117.0', 'ohe_Form completion date_120.0', 'ohe_Form completion date_121.0', 'ohe_Form completion date_123.0', 'ohe_Form completion date_124.0', 'ohe_Form completion date_127.0', 'ohe_Form completion date_128.0', 'ohe_Form completion date_130.0', 'ohe_Form completion date_131.0', 'ohe_Form completion date_132.0', 'ohe_Form completion date_133.0', 'ohe_Form completion date_134.0', 'ohe_Form completion date_135.0', 'ohe_Form completion date_136.0', 'ohe_Form completion date_137.0', 'ohe_Form completion date_138.0', 'ohe_Form completion date_139.0', 'ohe_Form completion date_140.0', 'ohe_Form completion date_142.0', 'ohe_Form completion date_144.0', 'ohe_Form completion date_146.0', 'ohe_Form completion date_147.0', 'ohe_Form completion date_148.0', 'ohe_Form completion date_150.0', 'ohe_Form completion date_152.0', 'ohe ...
# ['ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_0.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_1.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_2.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_4.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_5.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_6.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_7.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_8.0', 'ohe_American Joint Committee on Cancer Publication Version Type_0.0', 'ohe_American Joint Committee on Cancer Publication Version Type_1.0', 'ohe_American Joint Committee on Cancer Publication Version Type_2.0', 'ohe_American Joint Committee on Cancer Publication Version Type_3.0', 'ohe_American Joint Committee on Cancer Publication Version Type_4.0', 'ohe_Center of sequencing_0.0', 'ohe_Center of sequencing_1.0', 'ohe_Center of sequencing_2.0', 'ohe_Center of sequencing_3.0', 'ohe_Center of sequencing_4.0', 'ohe_Center of sequencing_6.0', 'ohe_Center of sequencing_7.0', 'ohe_Center of sequencing_8.0', 'ohe_Center of sequencing_9.0', 'ohe_Center of sequencing_10.0', 'ohe_Center of sequencing_11.0', 'ohe_Center of sequencing_12.0', 'ohe_Center of sequencing_13.0', 'ohe_Center of sequencing_14.0', 'ohe_Center of sequencing_16.0', 'ohe_Center of sequencing_17.0', 'ohe_Center of sequencing_18.0', 'ohe_Center of sequencing_19.0', 'ohe_Center of sequencing_20.0', 'ohe_Center of sequencing_21.0', 'ohe_Center of sequencing_22.0', 'ohe_Center of sequencing_23.0', 'ohe_Center of sequencing_24.0', 'ohe_Center of sequencing_25.0', 'ohe_Center of sequencing_26.0', 'ohe_Center of sequencing_27.0', 'ohe_Center of sequencing_28.0', 'ohe_Center of sequencing_29.0', 'ohe_Center of sequencing_30.0', 'ohe_Center of sequencing_31.0', 'ohe_Center of sequencing_32.0', 'ohe_Center of sequencing_33.0', 'ohe_Form completion date_0.0', 'ohe_Form completion date_1.0', 'ohe_Form completion date_2.0', 'ohe_Form completion date_3.0', 'ohe_Form completion date_4.0', 'ohe_Form completion date_5.0', 'ohe_Form completion date_6.0', 'ohe_Form completion date_7.0', 'ohe_Form completion date_8.0', 'ohe_Form completion date_9.0', 'ohe_Form completion date_10.0', 'ohe_Form completion date_11.0', 'ohe_Form completion date_12.0', 'ohe_Form completion date_15.0', 'ohe_Form completion date_16.0', 'ohe_Form completion date_17.0', 'ohe_Form completion date_18.0', 'ohe_Form completion date_19.0', 'ohe_Form completion date_21.0', 'ohe_Form completion date_22.0', 'ohe_Form completion date_23.0', 'ohe_Form completion date_24.0', 'ohe_Form completion date_26.0', 'ohe_Form completion date_27.0', 'ohe_Form completion date_29.0', 'ohe_Form completion date_30.0', 'ohe_Form completion date_31.0', 'ohe_Form completion date_32.0', 'ohe_Form completion date_33.0', 'ohe_Form completion date_34.0', 'ohe_Form completion date_35.0', 'ohe_Form completion date_36.0', 'ohe_Form completion date_38.0', 'ohe_Form completion date_39.0', 'ohe_Form completion date_40.0', 'ohe_Form completion date_41.0', 'ohe_Form completion date_42.0', 'ohe_Form completion date_43.0', 'ohe_Form completion date_44.0', 'ohe_Form completion date_45.0', 'ohe_Form completion date_46.0', 'ohe_Form completion date_48.0', 'ohe_Form completion date_49.0', 'ohe_Form completion date_51.0', 'ohe_Form completion date_52.0', 'ohe_Form completion date_54.0', 'ohe_Form completion date_55.0', 'ohe_Form completion date_57.0', 'ohe_Form completion date_59.0', 'ohe_Form completion date_60.0', 'ohe_Form completion date_63.0', 'ohe_Form completion date_64.0', 'ohe_Form completion date_65.0', 'ohe_Form completion date_66.0', 'ohe_Form completion date_67.0', 'ohe_Form completion date_68.0', 'ohe_Form completion date_69.0', 'ohe_Form completion date_70.0', 'ohe_Form completion date_71.0', 'ohe_Form completion date_72.0', 'ohe_Form completion date_73.0', 'o ...
# {'1q Status', '18q Status', '19p Status', '21 (21q) Status', 'Form completion date', 'ICD-10 Classification', '12q Status', '8p Status', 'Neoplasm Disease Lymph Node Stage American Joint Committee on Cancer Code', '12p Status', '20q Status', '3p Status', 'International Classification of Diseases for Oncology, Third Edition ICD-O-3 Histology Code', '19q Status', '14 (14q) Status', '2q Status', '16q Status', '6q Status', 'American Joint Committee on Cancer Metastasis Stage Code', '11p Status', '2p Status', '17p Status', '20p Status', '22 (22q) Status', 'Other Patient ID', '3q Status', '4q Status', 'American Joint Committee on Cancer Publication Version Type', 'Neoplasm Disease Stage American Joint Committee on Cancer Code', '18p Status', '6p Status', 'Tissue Source Site', 'American Joint Committee on Cancer Tumor Stage Code', '10p Status', '9q Status', '4p Status', '9p Status', 'Prior Diagnosis', '1p Status', '5p Status', '5q Status', 'Center of sequencing', 'International Classification of Diseases for Oncology, Third Edition ICD-O-3 Site Code', '15 (15q) Status', '17q Status', '7q Status', '8q Status', 'Tumor Type', '10q Status', 'Race Category', '11q Status', '7p Status', '16p Status', '13 (13q) Status'}
# {'1q Status': ['ohe_11q Status_0.0', 'ohe_11q Status_1.0', 'ohe_11q Status_2.0', 'ohe_1q Status_0.0', 'ohe_1q Status_1.0', 'ohe_1q Status_2.0'], '18q Status': ['ohe_18q Status_0.0', 'ohe_18q Status_1.0', 'ohe_18q Status_2.0'], '19p Status': ['ohe_19p Status_0.0', 'ohe_19p Status_1.0', 'ohe_19p Status_2.0'], '21 (21q) Status': ['ohe_21 (21q) Status_0.0', 'ohe_21 (21q) Status_1.0', 'ohe_21 (21q) Status_2.0'], 'Form completion date': ['ohe_Form completion date_0.0', 'ohe_Form completion date_1.0', 'ohe_Form completion date_2.0', 'ohe_Form completion date_3.0', 'ohe_Form completion date_4.0', 'ohe_Form completion date_5.0', 'ohe_Form completion date_6.0', 'ohe_Form completion date_7.0', 'ohe_Form completion date_8.0', 'ohe_Form completion date_9.0', 'ohe_Form completion date_10.0', 'ohe_Form completion date_11.0', 'ohe_Form completion date_12.0', 'ohe_Form completion date_15.0', 'ohe_Form completion date_16.0', 'ohe_Form completion date_17.0', 'ohe_Form completion date_18.0', 'ohe_Form completion date_19.0', 'ohe_Form completion date_21.0', 'ohe_Form completion date_22.0', 'ohe_Form completion date_23.0', 'ohe_Form completion date_24.0', 'ohe_Form completion date_26.0', 'ohe_Form completion date_27.0', 'ohe_Form completion date_29.0', 'ohe_Form completion date_30.0', 'ohe_Form completion date_31.0', 'ohe_Form completion date_32.0', 'ohe_Form completion date_33.0', 'ohe_Form completion date_34.0', 'ohe_Form completion date_35.0', 'ohe_Form completion date_36.0', 'ohe_Form completion date_38.0', 'ohe_Form completion date_39.0', 'ohe_Form completion date_40.0', 'ohe_Form completion date_41.0', 'ohe_Form completion date_42.0', 'ohe_Form completion date_43.0', 'ohe_Form completion date_44.0', 'ohe_Form completion date_45.0', 'ohe_Form completion date_46.0', 'ohe_Form completion date_48.0', 'ohe_Form completion date_49.0', 'ohe_Form completion date_51.0', 'ohe_Form completion date_52.0', 'ohe_Form completion date_54.0', 'ohe_Form completion date_55.0', 'ohe_Form completion date_57.0', 'ohe_Form completion date_59.0', 'ohe_Form completion date_60.0', 'ohe_Form completion date_63.0', 'ohe_Form completion date_64.0', 'ohe_Form completion date_65.0', 'ohe_Form completion date_66.0', 'ohe_Form completion date_67.0', 'ohe_Form completion date_68.0', 'ohe_Form completion date_69.0', 'ohe_Form completion date_70.0', 'ohe_Form completion date_71.0', 'ohe_Form completion date_72.0', 'ohe_Form completion date_73.0', 'ohe_Form completion date_74.0', 'ohe_Form completion date_75.0', 'ohe_Form completion date_76.0', 'ohe_Form completion date_77.0', 'ohe_Form completion date_78.0', 'ohe_Form completion date_79.0', 'ohe_Form completion date_80.0', 'ohe_Form completion date_81.0', 'ohe_Form completion date_82.0', 'ohe_Form completion date_83.0', 'ohe_Form completion date_84.0', 'ohe_Form completion date_85.0', 'ohe_Form completion date_87.0', 'ohe_Form completion date_88.0', 'ohe_Form completion date_89.0', 'ohe_Form completion date_90.0', 'ohe_Form completion date_91.0', 'ohe_Form completion date_92.0', 'ohe_Form completion date_93.0', 'ohe_Form completion date_94.0', 'ohe_Form completion date_95.0', 'ohe_Form completion date_96.0', 'ohe_Form completion date_98.0', 'ohe_Form completion date_99.0', 'ohe_Form completion date_100.0', 'ohe_Form completion date_101.0', 'ohe_Form completion date_102.0', 'ohe_Form completion date_103.0', 'ohe_Form completion date_104.0', 'ohe_Form completion date_105.0', 'ohe_Form completion date_107.0', 'ohe_Form completion date_108.0', 'ohe_Form completion date_109.0', 'ohe_Form completion date_110.0', 'ohe_Form completion date_111.0', 'ohe_Form completion date_112.0', 'ohe_Form completion date_113.0', 'ohe_Form completion date_114.0', 'ohe_Form completion date_116.0', 'ohe_Form completion date_117.0', 'ohe_Form completion date_118.0', 'ohe_Form completion date_120.0', 'ohe_Form completion date_122.0', 'ohe_Form completion date_123.0', 'ohe_Form completion date_124.0', 'ohe_Form completion date_125.0', 'ohe_Form completion  ...
# ['ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_0.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_1.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_2.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_3.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_4.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_5.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_6.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_7.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_8.0', 'ohe_American Joint Committee on Cancer Publication Version Type_0.0', 'ohe_American Joint Committee on Cancer Publication Version Type_1.0', 'ohe_American Joint Committee on Cancer Publication Version Type_2.0', 'ohe_American Joint Committee on Cancer Publication Version Type_3.0', 'ohe_American Joint Committee on Cancer Publication Version Type_4.0', 'ohe_Center of sequencing_0.0', 'ohe_Center of sequencing_1.0', 'ohe_Center of sequencing_2.0', 'ohe_Center of sequencing_3.0', 'ohe_Center of sequencing_4.0', 'ohe_Center of sequencing_5.0', 'ohe_Center of sequencing_6.0', 'ohe_Center of sequencing_7.0', 'ohe_Center of sequencing_8.0', 'ohe_Center of sequencing_9.0', 'ohe_Center of sequencing_10.0', 'ohe_Center of sequencing_11.0', 'ohe_Center of sequencing_12.0', 'ohe_Center of sequencing_13.0', 'ohe_Center of sequencing_14.0', 'ohe_Center of sequencing_16.0', 'ohe_Center of sequencing_17.0', 'ohe_Center of sequencing_18.0', 'ohe_Center of sequencing_19.0', 'ohe_Center of sequencing_20.0', 'ohe_Center of sequencing_21.0', 'ohe_Center of sequencing_22.0', 'ohe_Center of sequencing_23.0', 'ohe_Center of sequencing_24.0', 'ohe_Center of sequencing_25.0', 'ohe_Center of sequencing_26.0', 'ohe_Center of sequencing_27.0', 'ohe_Center of sequencing_28.0', 'ohe_Center of sequencing_29.0', 'ohe_Center of sequencing_30.0', 'ohe_Center of sequencing_31.0', 'ohe_Center of sequencing_32.0', 'ohe_Center of sequencing_33.0', 'ohe_Form completion date_0.0', 'ohe_Form completion date_1.0', 'ohe_Form completion date_2.0', 'ohe_Form completion date_3.0', 'ohe_Form completion date_4.0', 'ohe_Form completion date_5.0', 'ohe_Form completion date_6.0', 'ohe_Form completion date_7.0', 'ohe_Form completion date_8.0', 'ohe_Form completion date_10.0', 'ohe_Form completion date_11.0', 'ohe_Form completion date_12.0', 'ohe_Form completion date_13.0', 'ohe_Form completion date_15.0', 'ohe_Form completion date_16.0', 'ohe_Form completion date_17.0', 'ohe_Form completion date_18.0', 'ohe_Form completion date_19.0', 'ohe_Form completion date_20.0', 'ohe_Form completion date_21.0', 'ohe_Form completion date_22.0', 'ohe_Form completion date_23.0', 'ohe_Form completion date_24.0', 'ohe_Form completion date_25.0', 'ohe_Form completion date_26.0', 'ohe_Form completion date_27.0', 'ohe_Form completion date_28.0', 'ohe_Form completion date_29.0', 'ohe_Form completion date_30.0', 'ohe_Form completion date_31.0', 'ohe_Form completion date_33.0', 'ohe_Form completion date_34.0', 'ohe_Form completion date_35.0', 'ohe_Form completion date_36.0', 'ohe_Form completion date_37.0', 'ohe_Form completion date_38.0', 'ohe_Form completion date_39.0', 'ohe_Form completion date_40.0', 'ohe_Form completion date_41.0', 'ohe_Form completion date_42.0', 'ohe_Form completion date_43.0', 'ohe_Form completion date_44.0', 'ohe_Form completion date_45.0', 'ohe_Form completion date_46.0', 'ohe_Form completion date_47.0', 'ohe_Form completion date_48.0', 'ohe_Form completion date_49.0', 'ohe_Form completion date_50.0', 'ohe_Form completion date_51.0', 'ohe_Form completion date_52.0', 'ohe_Form completion date_55.0', 'ohe_Form completion date_56.0', 'ohe_Form completion date_57.0', 'ohe_Form completion date_58.0', 'ohe_Form completion date_59.0', 'ohe_Form completion date_60.0', 'ohe_Form completion date_61.0', 'ohe_Form completion date_6 ...
# {'1q Status', '18q Status', '19p Status', '21 (21q) Status', 'Form completion date', 'ICD-10 Classification', '12q Status', '8p Status', 'Neoplasm Disease Lymph Node Stage American Joint Committee on Cancer Code', '12p Status', '20q Status', '3p Status', 'International Classification of Diseases for Oncology, Third Edition ICD-O-3 Histology Code', '19q Status', '14 (14q) Status', '2q Status', '16q Status', '6q Status', 'American Joint Committee on Cancer Metastasis Stage Code', '11p Status', '2p Status', '17p Status', '20p Status', '22 (22q) Status', 'Other Patient ID', '3q Status', '4q Status', 'American Joint Committee on Cancer Publication Version Type', 'Neoplasm Disease Stage American Joint Committee on Cancer Code', '18p Status', '6p Status', 'Tissue Source Site', 'American Joint Committee on Cancer Tumor Stage Code', '10p Status', '9q Status', '4p Status', '9p Status', 'Prior Diagnosis', '1p Status', '5p Status', '5q Status', 'Center of sequencing', 'International Classification of Diseases for Oncology, Third Edition ICD-O-3 Site Code', '15 (15q) Status', '17q Status', '7q Status', '8q Status', 'Tumor Type', '10q Status', 'Race Category', '11q Status', '7p Status', '16p Status', '13 (13q) Status'}
# {'1q Status': ['ohe_11q Status_0.0', 'ohe_11q Status_1.0', 'ohe_11q Status_2.0', 'ohe_1q Status_0.0', 'ohe_1q Status_1.0', 'ohe_1q Status_2.0'], '18q Status': ['ohe_18q Status_0.0', 'ohe_18q Status_1.0', 'ohe_18q Status_2.0'], '19p Status': ['ohe_19p Status_0.0', 'ohe_19p Status_1.0', 'ohe_19p Status_2.0'], '21 (21q) Status': ['ohe_21 (21q) Status_0.0', 'ohe_21 (21q) Status_1.0', 'ohe_21 (21q) Status_2.0'], 'Form completion date': ['ohe_Form completion date_0.0', 'ohe_Form completion date_1.0', 'ohe_Form completion date_2.0', 'ohe_Form completion date_3.0', 'ohe_Form completion date_4.0', 'ohe_Form completion date_5.0', 'ohe_Form completion date_6.0', 'ohe_Form completion date_7.0', 'ohe_Form completion date_8.0', 'ohe_Form completion date_10.0', 'ohe_Form completion date_11.0', 'ohe_Form completion date_12.0', 'ohe_Form completion date_13.0', 'ohe_Form completion date_15.0', 'ohe_Form completion date_16.0', 'ohe_Form completion date_17.0', 'ohe_Form completion date_18.0', 'ohe_Form completion date_19.0', 'ohe_Form completion date_20.0', 'ohe_Form completion date_21.0', 'ohe_Form completion date_22.0', 'ohe_Form completion date_23.0', 'ohe_Form completion date_24.0', 'ohe_Form completion date_25.0', 'ohe_Form completion date_26.0', 'ohe_Form completion date_27.0', 'ohe_Form completion date_28.0', 'ohe_Form completion date_29.0', 'ohe_Form completion date_30.0', 'ohe_Form completion date_31.0', 'ohe_Form completion date_33.0', 'ohe_Form completion date_34.0', 'ohe_Form completion date_35.0', 'ohe_Form completion date_36.0', 'ohe_Form completion date_37.0', 'ohe_Form completion date_38.0', 'ohe_Form completion date_39.0', 'ohe_Form completion date_40.0', 'ohe_Form completion date_41.0', 'ohe_Form completion date_42.0', 'ohe_Form completion date_43.0', 'ohe_Form completion date_44.0', 'ohe_Form completion date_45.0', 'ohe_Form completion date_46.0', 'ohe_Form completion date_47.0', 'ohe_Form completion date_48.0', 'ohe_Form completion date_49.0', 'ohe_Form completion date_50.0', 'ohe_Form completion date_51.0', 'ohe_Form completion date_52.0', 'ohe_Form completion date_55.0', 'ohe_Form completion date_56.0', 'ohe_Form completion date_57.0', 'ohe_Form completion date_58.0', 'ohe_Form completion date_59.0', 'ohe_Form completion date_60.0', 'ohe_Form completion date_61.0', 'ohe_Form completion date_62.0', 'ohe_Form completion date_63.0', 'ohe_Form completion date_64.0', 'ohe_Form completion date_65.0', 'ohe_Form completion date_66.0', 'ohe_Form completion date_68.0', 'ohe_Form completion date_69.0', 'ohe_Form completion date_70.0', 'ohe_Form completion date_71.0', 'ohe_Form completion date_72.0', 'ohe_Form completion date_73.0', 'ohe_Form completion date_74.0', 'ohe_Form completion date_75.0', 'ohe_Form completion date_76.0', 'ohe_Form completion date_78.0', 'ohe_Form completion date_79.0', 'ohe_Form completion date_80.0', 'ohe_Form completion date_81.0', 'ohe_Form completion date_82.0', 'ohe_Form completion date_83.0', 'ohe_Form completion date_84.0', 'ohe_Form completion date_85.0', 'ohe_Form completion date_86.0', 'ohe_Form completion date_87.0', 'ohe_Form completion date_88.0', 'ohe_Form completion date_89.0', 'ohe_Form completion date_90.0', 'ohe_Form completion date_91.0', 'ohe_Form completion date_92.0', 'ohe_Form completion date_93.0', 'ohe_Form completion date_94.0', 'ohe_Form completion date_95.0', 'ohe_Form completion date_96.0', 'ohe_Form completion date_97.0', 'ohe_Form completion date_98.0', 'ohe_Form completion date_99.0', 'ohe_Form completion date_100.0', 'ohe_Form completion date_101.0', 'ohe_Form completion date_102.0', 'ohe_Form completion date_103.0', 'ohe_Form completion date_104.0', 'ohe_Form completion date_105.0', 'ohe_Form completion date_107.0', 'ohe_Form completion date_108.0', 'ohe_Form completion date_109.0', 'ohe_Form completion date_110.0', 'ohe_Form completion date_111.0', 'ohe_Form completion date_112.0', 'ohe_Form completion date_114.0', 'ohe_Form completion date_115.0', 'ohe_Form completion date_11 ...
# ['ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_0.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_1.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_2.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_3.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_4.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_5.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_6.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_7.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_8.0', 'ohe_American Joint Committee on Cancer Publication Version Type_0.0', 'ohe_American Joint Committee on Cancer Publication Version Type_1.0', 'ohe_American Joint Committee on Cancer Publication Version Type_2.0', 'ohe_American Joint Committee on Cancer Publication Version Type_3.0', 'ohe_American Joint Committee on Cancer Publication Version Type_4.0', 'ohe_Center of sequencing_0.0', 'ohe_Center of sequencing_1.0', 'ohe_Center of sequencing_3.0', 'ohe_Center of sequencing_4.0', 'ohe_Center of sequencing_5.0', 'ohe_Center of sequencing_6.0', 'ohe_Center of sequencing_7.0', 'ohe_Center of sequencing_8.0', 'ohe_Center of sequencing_9.0', 'ohe_Center of sequencing_12.0', 'ohe_Center of sequencing_13.0', 'ohe_Center of sequencing_14.0', 'ohe_Center of sequencing_16.0', 'ohe_Center of sequencing_17.0', 'ohe_Center of sequencing_18.0', 'ohe_Center of sequencing_19.0', 'ohe_Center of sequencing_20.0', 'ohe_Center of sequencing_21.0', 'ohe_Center of sequencing_22.0', 'ohe_Center of sequencing_23.0', 'ohe_Center of sequencing_24.0', 'ohe_Center of sequencing_25.0', 'ohe_Center of sequencing_26.0', 'ohe_Center of sequencing_27.0', 'ohe_Center of sequencing_28.0', 'ohe_Center of sequencing_29.0', 'ohe_Center of sequencing_30.0', 'ohe_Center of sequencing_31.0', 'ohe_Center of sequencing_32.0', 'ohe_Center of sequencing_33.0', 'ohe_Form completion date_1.0', 'ohe_Form completion date_2.0', 'ohe_Form completion date_3.0', 'ohe_Form completion date_4.0', 'ohe_Form completion date_5.0', 'ohe_Form completion date_7.0', 'ohe_Form completion date_8.0', 'ohe_Form completion date_9.0', 'ohe_Form completion date_10.0', 'ohe_Form completion date_12.0', 'ohe_Form completion date_13.0', 'ohe_Form completion date_14.0', 'ohe_Form completion date_16.0', 'ohe_Form completion date_17.0', 'ohe_Form completion date_18.0', 'ohe_Form completion date_19.0', 'ohe_Form completion date_22.0', 'ohe_Form completion date_24.0', 'ohe_Form completion date_26.0', 'ohe_Form completion date_27.0', 'ohe_Form completion date_28.0', 'ohe_Form completion date_30.0', 'ohe_Form completion date_31.0', 'ohe_Form completion date_33.0', 'ohe_Form completion date_35.0', 'ohe_Form completion date_36.0', 'ohe_Form completion date_37.0', 'ohe_Form completion date_38.0', 'ohe_Form completion date_39.0', 'ohe_Form completion date_40.0', 'ohe_Form completion date_41.0', 'ohe_Form completion date_42.0', 'ohe_Form completion date_43.0', 'ohe_Form completion date_47.0', 'ohe_Form completion date_49.0', 'ohe_Form completion date_50.0', 'ohe_Form completion date_51.0', 'ohe_Form completion date_52.0', 'ohe_Form completion date_53.0', 'ohe_Form completion date_54.0', 'ohe_Form completion date_55.0', 'ohe_Form completion date_56.0', 'ohe_Form completion date_57.0', 'ohe_Form completion date_60.0', 'ohe_Form completion date_61.0', 'ohe_Form completion date_63.0', 'ohe_Form completion date_64.0', 'ohe_Form completion date_65.0', 'ohe_Form completion date_67.0', 'ohe_Form completion date_68.0', 'ohe_Form completion date_69.0', 'ohe_Form completion date_71.0', 'ohe_Form completion date_72.0', 'ohe_Form completion date_74.0', 'ohe_Form completion date_75.0', 'ohe_Form completion date_76.0', 'ohe_Form completion date_78.0', 'ohe_Form completion date_79.0', 'ohe_Form completion date_80.0', 'ohe_Form completion date_81.0', 'ohe_Form completion date ...
# {'1q Status', '18q Status', '19p Status', '21 (21q) Status', 'Form completion date', 'ICD-10 Classification', '12q Status', '8p Status', 'Neoplasm Disease Lymph Node Stage American Joint Committee on Cancer Code', '12p Status', '20q Status', '3p Status', 'International Classification of Diseases for Oncology, Third Edition ICD-O-3 Histology Code', '19q Status', '14 (14q) Status', '2q Status', '16q Status', '6q Status', 'American Joint Committee on Cancer Metastasis Stage Code', '11p Status', '2p Status', '17p Status', '20p Status', '22 (22q) Status', 'Other Patient ID', '3q Status', '4q Status', 'American Joint Committee on Cancer Publication Version Type', 'Neoplasm Disease Stage American Joint Committee on Cancer Code', '18p Status', '6p Status', 'Tissue Source Site', 'American Joint Committee on Cancer Tumor Stage Code', '10p Status', '9q Status', '4p Status', '9p Status', 'Prior Diagnosis', '1p Status', '5p Status', '5q Status', 'Center of sequencing', 'International Classification of Diseases for Oncology, Third Edition ICD-O-3 Site Code', '15 (15q) Status', '17q Status', '7q Status', '8q Status', 'Tumor Type', '10q Status', 'Race Category', '11q Status', '7p Status', '16p Status', '13 (13q) Status'}
# {'1q Status': ['ohe_11q Status_0.0', 'ohe_11q Status_1.0', 'ohe_11q Status_2.0', 'ohe_1q Status_0.0', 'ohe_1q Status_1.0', 'ohe_1q Status_2.0'], '18q Status': ['ohe_18q Status_0.0', 'ohe_18q Status_1.0', 'ohe_18q Status_2.0'], '19p Status': ['ohe_19p Status_0.0', 'ohe_19p Status_1.0', 'ohe_19p Status_2.0'], '21 (21q) Status': ['ohe_21 (21q) Status_0.0', 'ohe_21 (21q) Status_1.0', 'ohe_21 (21q) Status_2.0'], 'Form completion date': ['ohe_Form completion date_1.0', 'ohe_Form completion date_2.0', 'ohe_Form completion date_3.0', 'ohe_Form completion date_4.0', 'ohe_Form completion date_5.0', 'ohe_Form completion date_7.0', 'ohe_Form completion date_8.0', 'ohe_Form completion date_9.0', 'ohe_Form completion date_10.0', 'ohe_Form completion date_12.0', 'ohe_Form completion date_13.0', 'ohe_Form completion date_14.0', 'ohe_Form completion date_16.0', 'ohe_Form completion date_17.0', 'ohe_Form completion date_18.0', 'ohe_Form completion date_19.0', 'ohe_Form completion date_22.0', 'ohe_Form completion date_24.0', 'ohe_Form completion date_26.0', 'ohe_Form completion date_27.0', 'ohe_Form completion date_28.0', 'ohe_Form completion date_30.0', 'ohe_Form completion date_31.0', 'ohe_Form completion date_33.0', 'ohe_Form completion date_35.0', 'ohe_Form completion date_36.0', 'ohe_Form completion date_37.0', 'ohe_Form completion date_38.0', 'ohe_Form completion date_39.0', 'ohe_Form completion date_40.0', 'ohe_Form completion date_41.0', 'ohe_Form completion date_42.0', 'ohe_Form completion date_43.0', 'ohe_Form completion date_47.0', 'ohe_Form completion date_49.0', 'ohe_Form completion date_50.0', 'ohe_Form completion date_51.0', 'ohe_Form completion date_52.0', 'ohe_Form completion date_53.0', 'ohe_Form completion date_54.0', 'ohe_Form completion date_55.0', 'ohe_Form completion date_56.0', 'ohe_Form completion date_57.0', 'ohe_Form completion date_60.0', 'ohe_Form completion date_61.0', 'ohe_Form completion date_63.0', 'ohe_Form completion date_64.0', 'ohe_Form completion date_65.0', 'ohe_Form completion date_67.0', 'ohe_Form completion date_68.0', 'ohe_Form completion date_69.0', 'ohe_Form completion date_71.0', 'ohe_Form completion date_72.0', 'ohe_Form completion date_74.0', 'ohe_Form completion date_75.0', 'ohe_Form completion date_76.0', 'ohe_Form completion date_78.0', 'ohe_Form completion date_79.0', 'ohe_Form completion date_80.0', 'ohe_Form completion date_81.0', 'ohe_Form completion date_82.0', 'ohe_Form completion date_83.0', 'ohe_Form completion date_84.0', 'ohe_Form completion date_85.0', 'ohe_Form completion date_87.0', 'ohe_Form completion date_88.0', 'ohe_Form completion date_89.0', 'ohe_Form completion date_91.0', 'ohe_Form completion date_94.0', 'ohe_Form completion date_95.0', 'ohe_Form completion date_97.0', 'ohe_Form completion date_98.0', 'ohe_Form completion date_99.0', 'ohe_Form completion date_100.0', 'ohe_Form completion date_101.0', 'ohe_Form completion date_102.0', 'ohe_Form completion date_104.0', 'ohe_Form completion date_105.0', 'ohe_Form completion date_106.0', 'ohe_Form completion date_110.0', 'ohe_Form completion date_111.0', 'ohe_Form completion date_114.0', 'ohe_Form completion date_115.0', 'ohe_Form completion date_116.0', 'ohe_Form completion date_117.0', 'ohe_Form completion date_118.0', 'ohe_Form completion date_119.0', 'ohe_Form completion date_120.0', 'ohe_Form completion date_121.0', 'ohe_Form completion date_122.0', 'ohe_Form completion date_123.0', 'ohe_Form completion date_124.0', 'ohe_Form completion date_126.0', 'ohe_Form completion date_127.0', 'ohe_Form completion date_128.0', 'ohe_Form completion date_130.0', 'ohe_Form completion date_131.0', 'ohe_Form completion date_132.0', 'ohe_Form completion date_133.0', 'ohe_Form completion date_135.0', 'ohe_Form completion date_136.0', 'ohe_Form completion date_139.0', 'ohe_Form completion date_140.0', 'ohe_Form completion date_141.0', 'ohe_Form completion date_142.0', 'ohe_Form completion date_144.0', 'ohe_Form completion date_147.0', 'ohe_Fo ...
# ...
# {'1q Status', '18q Status', '19p Status', '21 (21q) Status', 'Form completion date', 'ICD-10 Classification', '12q Status', '8p Status', 'Neoplasm Disease Lymph Node Stage American Joint Committee on Cancer Code', '12p Status', '20q Status', '3p Status', 'International Classification of Diseases for Oncology, Third Edition ICD-O-3 Histology Code', '19q Status', '14 (14q) Status', '2q Status', '16q Status', '6q Status', 'American Joint Committee on Cancer Metastasis Stage Code', '11p Status', '2p Status', '17p Status', '20p Status', '22 (22q) Status', 'Other Patient ID', '3q Status', '4q Status', 'American Joint Committee on Cancer Publication Version Type', 'Neoplasm Disease Stage American Joint Committee on Cancer Code', '18p Status', '6p Status', 'Tissue Source Site', 'American Joint Committee on Cancer Tumor Stage Code', '10p Status', '9q Status', '4p Status', '9p Status', 'Prior Diagnosis', '1p Status', '5p Status', '5q Status', 'Center of sequencing', 'International Classification of Diseases for Oncology, Third Edition ICD-O-3 Site Code', '15 (15q) Status', '17q Status', '7q Status', '8q Status', 'Tumor Type', '10q Status', 'Race Category', '11q Status', '7p Status', '16p Status', '13 (13q) Status'}
# {'1q Status': ['ohe_11q Status_0.0', 'ohe_11q Status_1.0', 'ohe_11q Status_2.0', 'ohe_1q Status_0.0', 'ohe_1q Status_1.0', 'ohe_1q Status_2.0'], '18q Status': ['ohe_18q Status_0.0', 'ohe_18q Status_1.0', 'ohe_18q Status_2.0'], '19p Status': ['ohe_19p Status_0.0', 'ohe_19p Status_1.0', 'ohe_19p Status_2.0'], '21 (21q) Status': ['ohe_21 (21q) Status_0.0', 'ohe_21 (21q) Status_1.0', 'ohe_21 (21q) Status_2.0'], 'Form completion date': ['ohe_Form completion date_1.0', 'ohe_Form completion date_2.0', 'ohe_Form completion date_4.0', 'ohe_Form completion date_5.0', 'ohe_Form completion date_6.0', 'ohe_Form completion date_7.0', 'ohe_Form completion date_8.0', 'ohe_Form completion date_9.0', 'ohe_Form completion date_10.0', 'ohe_Form completion date_11.0', 'ohe_Form completion date_13.0', 'ohe_Form completion date_14.0', 'ohe_Form completion date_15.0', 'ohe_Form completion date_16.0', 'ohe_Form completion date_17.0', 'ohe_Form completion date_19.0', 'ohe_Form completion date_23.0', 'ohe_Form completion date_25.0', 'ohe_Form completion date_26.0', 'ohe_Form completion date_28.0', 'ohe_Form completion date_29.0', 'ohe_Form completion date_30.0', 'ohe_Form completion date_31.0', 'ohe_Form completion date_32.0', 'ohe_Form completion date_33.0', 'ohe_Form completion date_34.0', 'ohe_Form completion date_36.0', 'ohe_Form completion date_37.0', 'ohe_Form completion date_38.0', 'ohe_Form completion date_40.0', 'ohe_Form completion date_41.0', 'ohe_Form completion date_42.0', 'ohe_Form completion date_45.0', 'ohe_Form completion date_46.0', 'ohe_Form completion date_47.0', 'ohe_Form completion date_48.0', 'ohe_Form completion date_49.0', 'ohe_Form completion date_51.0', 'ohe_Form completion date_52.0', 'ohe_Form completion date_54.0', 'ohe_Form completion date_57.0', 'ohe_Form completion date_58.0', 'ohe_Form completion date_59.0', 'ohe_Form completion date_60.0', 'ohe_Form completion date_61.0', 'ohe_Form completion date_62.0', 'ohe_Form completion date_63.0', 'ohe_Form completion date_64.0', 'ohe_Form completion date_68.0', 'ohe_Form completion date_69.0', 'ohe_Form completion date_70.0', 'ohe_Form completion date_72.0', 'ohe_Form completion date_74.0', 'ohe_Form completion date_79.0', 'ohe_Form completion date_80.0', 'ohe_Form completion date_81.0', 'ohe_Form completion date_82.0', 'ohe_Form completion date_83.0', 'ohe_Form completion date_85.0', 'ohe_Form completion date_86.0', 'ohe_Form completion date_87.0', 'ohe_Form completion date_88.0', 'ohe_Form completion date_91.0', 'ohe_Form completion date_93.0', 'ohe_Form completion date_94.0', 'ohe_Form completion date_95.0', 'ohe_Form completion date_96.0', 'ohe_Form completion date_99.0', 'ohe_Form completion date_100.0', 'ohe_Form completion date_101.0', 'ohe_Form completion date_102.0', 'ohe_Form completion date_108.0', 'ohe_Form completion date_109.0', 'ohe_Form completion date_111.0', 'ohe_Form completion date_113.0', 'ohe_Form completion date_116.0', 'ohe_Form completion date_117.0', 'ohe_Form completion date_119.0', 'ohe_Form completion date_120.0', 'ohe_Form completion date_121.0', 'ohe_Form completion date_122.0', 'ohe_Form completion date_123.0', 'ohe_Form completion date_124.0', 'ohe_Form completion date_126.0', 'ohe_Form completion date_127.0', 'ohe_Form completion date_129.0', 'ohe_Form completion date_130.0', 'ohe_Form completion date_131.0', 'ohe_Form completion date_133.0', 'ohe_Form completion date_134.0', 'ohe_Form completion date_135.0', 'ohe_Form completion date_136.0', 'ohe_Form completion date_137.0', 'ohe_Form completion date_138.0', 'ohe_Form completion date_139.0', 'ohe_Form completion date_140.0', 'ohe_Form completion date_142.0', 'ohe_Form completion date_143.0', 'ohe_Form completion date_144.0', 'ohe_Form completion date_148.0', 'ohe_Form completion date_150.0', 'ohe_Form completion date_152.0', 'ohe_Form completion date_154.0', 'ohe_Form completion date_155.0', 'ohe_Form completion date_156.0', 'ohe_Form completion date_158.0', 'ohe_Form completion date_163.0', 'o ...
# ['ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_0.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_1.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_2.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_3.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_4.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_5.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_6.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_7.0', 'ohe_Neoplasm Disease Stage American Joint Committee on Cancer Code_8.0', 'ohe_American Joint Committee on Cancer Publication Version Type_0.0', 'ohe_American Joint Committee on Cancer Publication Version Type_1.0', 'ohe_American Joint Committee on Cancer Publication Version Type_2.0', 'ohe_American Joint Committee on Cancer Publication Version Type_3.0', 'ohe_American Joint Committee on Cancer Publication Version Type_4.0', 'ohe_Center of sequencing_0.0', 'ohe_Center of sequencing_1.0', 'ohe_Center of sequencing_2.0', 'ohe_Center of sequencing_3.0', 'ohe_Center of sequencing_4.0', 'ohe_Center of sequencing_6.0', 'ohe_Center of sequencing_7.0', 'ohe_Center of sequencing_8.0', 'ohe_Center of sequencing_9.0', 'ohe_Center of sequencing_10.0', 'ohe_Center of sequencing_11.0', 'ohe_Center of sequencing_12.0', 'ohe_Center of sequencing_13.0', 'ohe_Center of sequencing_14.0', 'ohe_Center of sequencing_15.0', 'ohe_Center of sequencing_16.0', 'ohe_Center of sequencing_17.0', 'ohe_Center of sequencing_18.0', 'ohe_Center of sequencing_19.0', 'ohe_Center of sequencing_20.0', 'ohe_Center of sequencing_21.0', 'ohe_Center of sequencing_22.0', 'ohe_Center of sequencing_23.0', 'ohe_Center of sequencing_24.0', 'ohe_Center of sequencing_25.0', 'ohe_Center of sequencing_26.0', 'ohe_Center of sequencing_27.0', 'ohe_Center of sequencing_28.0', 'ohe_Center of sequencing_29.0', 'ohe_Center of sequencing_30.0', 'ohe_Center of sequencing_31.0', 'ohe_Center of sequencing_32.0', 'ohe_Center of sequencing_33.0', 'ohe_Form completion date_0.0', 'ohe_Form completion date_1.0', 'ohe_Form completion date_2.0', 'ohe_Form completion date_3.0', 'ohe_Form completion date_4.0', 'ohe_Form completion date_5.0', 'ohe_Form completion date_6.0', 'ohe_Form completion date_7.0', 'ohe_Form completion date_8.0', 'ohe_Form completion date_10.0', 'ohe_Form completion date_11.0', 'ohe_Form completion date_13.0', 'ohe_Form completion date_14.0', 'ohe_Form completion date_15.0', 'ohe_Form completion date_16.0', 'ohe_Form completion date_17.0', 'ohe_Form completion date_18.0', 'ohe_Form completion date_19.0', 'ohe_Form completion date_20.0', 'ohe_Form completion date_21.0', 'ohe_Form completion date_22.0', 'ohe_Form completion date_23.0', 'ohe_Form completion date_24.0', 'ohe_Form completion date_25.0', 'ohe_Form completion date_26.0', 'ohe_Form completion date_27.0', 'ohe_Form completion date_28.0', 'ohe_Form completion date_29.0', 'ohe_Form completion date_30.0', 'ohe_Form completion date_31.0', 'ohe_Form completion date_32.0', 'ohe_Form completion date_33.0', 'ohe_Form completion date_34.0', 'ohe_Form completion date_35.0', 'ohe_Form completion date_36.0', 'ohe_Form completion date_37.0', 'ohe_Form completion date_38.0', 'ohe_Form completion date_39.0', 'ohe_Form completion date_40.0', 'ohe_Form completion date_41.0', 'ohe_Form completion date_42.0', 'ohe_Form completion date_43.0', 'ohe_Form completion date_44.0', 'ohe_Form completion date_45.0', 'ohe_Form completion date_46.0', 'ohe_Form completion date_47.0', 'ohe_Form completion date_48.0', 'ohe_Form completion date_49.0', 'ohe_Form completion date_50.0', 'ohe_Form completion date_51.0', 'ohe_Form completion date_52.0', 'ohe_Form completion date_53.0', 'ohe_Form completion date_54.0', 'ohe_Form completion date_55.0', 'ohe_Form completion date_56.0', 'ohe_Form completion date_57.0', 'ohe_Form completion date_58.0', 'ohe_Form completion date_ ...
# {'1q Status', '18q Status', '19p Status', '21 (21q) Status', 'Form completion date', 'ICD-10 Classification', '12q Status', '8p Status', 'Neoplasm Disease Lymph Node Stage American Joint Committee on Cancer Code', '12p Status', '20q Status', '3p Status', 'International Classification of Diseases for Oncology, Third Edition ICD-O-3 Histology Code', '19q Status', '14 (14q) Status', '2q Status', '16q Status', '6q Status', 'American Joint Committee on Cancer Metastasis Stage Code', '11p Status', '2p Status', '17p Status', '20p Status', '22 (22q) Status', 'Other Patient ID', '3q Status', '4q Status', 'American Joint Committee on Cancer Publication Version Type', 'Neoplasm Disease Stage American Joint Committee on Cancer Code', '18p Status', '6p Status', 'Tissue Source Site', 'American Joint Committee on Cancer Tumor Stage Code', '10p Status', '9q Status', '4p Status', '9p Status', 'Prior Diagnosis', '1p Status', '5p Status', '5q Status', 'Center of sequencing', 'International Classification of Diseases for Oncology, Third Edition ICD-O-3 Site Code', '15 (15q) Status', '17q Status', '7q Status', '8q Status', 'Tumor Type', '10q Status', 'Race Category', '11q Status', '7p Status', '16p Status', '13 (13q) Status'}
# {'1q Status': ['ohe_11q Status_0.0', 'ohe_11q Status_1.0', 'ohe_11q Status_2.0', 'ohe_1q Status_0.0', 'ohe_1q Status_1.0', 'ohe_1q Status_2.0'], '18q Status': ['ohe_18q Status_0.0', 'ohe_18q Status_1.0', 'ohe_18q Status_2.0'], '19p Status': ['ohe_19p Status_0.0', 'ohe_19p Status_1.0', 'ohe_19p Status_2.0'], '21 (21q) Status': ['ohe_21 (21q) Status_0.0', 'ohe_21 (21q) Status_1.0', 'ohe_21 (21q) Status_2.0'], 'Form completion date': ['ohe_Form completion date_0.0', 'ohe_Form completion date_1.0', 'ohe_Form completion date_2.0', 'ohe_Form completion date_3.0', 'ohe_Form completion date_4.0', 'ohe_Form completion date_5.0', 'ohe_Form completion date_6.0', 'ohe_Form completion date_7.0', 'ohe_Form completion date_8.0', 'ohe_Form completion date_10.0', 'ohe_Form completion date_11.0', 'ohe_Form completion date_13.0', 'ohe_Form completion date_14.0', 'ohe_Form completion date_15.0', 'ohe_Form completion date_16.0', 'ohe_Form completion date_17.0', 'ohe_Form completion date_18.0', 'ohe_Form completion date_19.0', 'ohe_Form completion date_20.0', 'ohe_Form completion date_21.0', 'ohe_Form completion date_22.0', 'ohe_Form completion date_23.0', 'ohe_Form completion date_24.0', 'ohe_Form completion date_25.0', 'ohe_Form completion date_26.0', 'ohe_Form completion date_27.0', 'ohe_Form completion date_28.0', 'ohe_Form completion date_29.0', 'ohe_Form completion date_30.0', 'ohe_Form completion date_31.0', 'ohe_Form completion date_32.0', 'ohe_Form completion date_33.0', 'ohe_Form completion date_34.0', 'ohe_Form completion date_35.0', 'ohe_Form completion date_36.0', 'ohe_Form completion date_37.0', 'ohe_Form completion date_38.0', 'ohe_Form completion date_39.0', 'ohe_Form completion date_40.0', 'ohe_Form completion date_41.0', 'ohe_Form completion date_42.0', 'ohe_Form completion date_43.0', 'ohe_Form completion date_44.0', 'ohe_Form completion date_45.0', 'ohe_Form completion date_46.0', 'ohe_Form completion date_47.0', 'ohe_Form completion date_48.0', 'ohe_Form completion date_49.0', 'ohe_Form completion date_50.0', 'ohe_Form completion date_51.0', 'ohe_Form completion date_52.0', 'ohe_Form completion date_53.0', 'ohe_Form completion date_54.0', 'ohe_Form completion date_55.0', 'ohe_Form completion date_56.0', 'ohe_Form completion date_57.0', 'ohe_Form completion date_58.0', 'ohe_Form completion date_59.0', 'ohe_Form completion date_60.0', 'ohe_Form completion date_61.0', 'ohe_Form completion date_62.0', 'ohe_Form completion date_63.0', 'ohe_Form completion date_64.0', 'ohe_Form completion date_66.0', 'ohe_Form completion date_67.0', 'ohe_Form completion date_68.0', 'ohe_Form completion date_69.0', 'ohe_Form completion date_70.0', 'ohe_Form completion date_71.0', 'ohe_Form completion date_72.0', 'ohe_Form completion date_73.0', 'ohe_Form completion date_74.0', 'ohe_Form completion date_75.0', 'ohe_Form completion date_76.0', 'ohe_Form completion date_77.0', 'ohe_Form completion date_78.0', 'ohe_Form completion date_79.0', 'ohe_Form completion date_80.0', 'ohe_Form completion date_81.0', 'ohe_Form completion date_82.0', 'ohe_Form completion date_83.0', 'ohe_Form completion date_84.0', 'ohe_Form completion date_85.0', 'ohe_Form completion date_86.0', 'ohe_Form completion date_87.0', 'ohe_Form completion date_88.0', 'ohe_Form completion date_89.0', 'ohe_Form completion date_91.0', 'ohe_Form completion date_92.0', 'ohe_Form completion date_93.0', 'ohe_Form completion date_94.0', 'ohe_Form completion date_95.0', 'ohe_Form completion date_98.0', 'ohe_Form completion date_99.0', 'ohe_Form completion date_100.0', 'ohe_Form completion date_101.0', 'ohe_Form completion date_102.0', 'ohe_Form completion date_103.0', 'ohe_Form completion date_104.0', 'ohe_Form completion date_105.0', 'ohe_Form completion date_106.0', 'ohe_Form completion date_107.0', 'ohe_Form completion date_108.0', 'ohe_Form completion date_109.0', 'ohe_Form completion date_110.0', 'ohe_Form completion date_111.0', 'ohe_Form completion date_112.0', 'ohe_Form completion date_114 ...
